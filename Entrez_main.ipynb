# %% [markdown]
# # Defining Types of Articles

# %%
systematic_meta_analysis = [
    "Meta-Analysis",
    "Network Meta-Analysis",
    "Systematic Review"
    ]

# %%
clinical_trial = [
    "Adaptive Clinical Trial",
    "Clinical Study",
    "Clinical Trial",
    "Clinical Trial Protocol",
    "Clinical Trial, Phase I",
    "Clinical Trial, Phase II",
    "Clinical Trial, Phase III",
    "Clinical Trial, Phase IV",
    "Clinical Trial, Veterinary",
    "Controlled Clinical Trial",
    "Equivalence Trial",
    "Multicenter Study",
    "Pragmatic Clinical Trial",
    "Randomized Controlled Trial",
    "Randomized Controlled Trial, Veterinary"
]

# %%
observational_studies = [
    "Case Reports",
    "Comparative Study",
    "Evaluation Study",
    "Observational Study",
    "Observational Study, Veterinary",
    "Twin Study",
    "Validation Study",
    "Review",
    "Scientific Integrity Review",
    "Scoping Review"
]

# %%
# Initialize an empty list
all_study_types = []

# Extend the list with other lists
all_study_types.extend(systematic_meta_analysis)
all_study_types.extend(clinical_trial)
all_study_types.extend(observational_studies)

allowed_study_types = all_study_types

# Print the combined list
print("Total Study types:",len(all_study_types))
# Out:
# Total Study types: 28

# %% [markdown]
# # Loading Data

# %%
import pandas as pd

# Read Excel file
df = pd.read_excel('Data/entrez_ingredients_with_synonyms.xlsx')  # For .xls or .xlsx

# View first 5 rows
df.head()
# Out:
#             Root Name      PMID  \
# 0  Acetyl L-Carnitine  10022226
# 1  Acetyl L-Carnitine  10030388
# 2  Acetyl L-Carnitine  10036643
# 3  Acetyl L-Carnitine  10052020
# 4  Acetyl L-Carnitine  10067662
#
#                                                Title  \
# 0     Micronutrients prevent cancer and delay aging.
# 1  Significance of skeletal muscle properties on ...
# 2  Cellular dysmetabolism: the dark side of HIV-1...
# 3  Substrate utilization and work efficiency duri...
# 4  L-carnitine improves glucose disposal in type ...
#
#                                         Article Type  Publication Year  \
# 0  Journal Article; Research Support, Non-U.S. Go...              1998
# 1  Comparative Study; Journal Article; Research S...              1999
# 2                            Journal Article; Review              1996
# 3  Clinical Trial; Controlled Clinical Trial; Jou...              1999
# 4  Clinical Trial; Controlled Clinical Trial; Jou...              1999
#
#                                   PubMed URL Search Term(s)
# 0  https://pubmed.ncbi.nlm.nih.gov/10022226/      Carnitine
# 1  https://pubmed.ncbi.nlm.nih.gov/10030388/      Carnitine
# 2  https://pubmed.ncbi.nlm.nih.gov/10036643/      Carnitine
# 3  https://pubmed.ncbi.nlm.nih.gov/10052020/      Carnitine
# 4  https://pubmed.ncbi.nlm.nih.gov/10067662/      Carnitine

# %%
df.shape
# Out:
# (277397, 7)

# %% [markdown]
# # Adding Synonyms

# %%
import numpy as np

synonyms_df = pd.read_excel("Data/76 Ingredient List.xlsx")
synonyms_df['Common Name(s)'] = synonyms_df['Common Name(s)'].astype(str).str.replace(',', ';')
synonyms_df['Other Search Words'] = synonyms_df['Other Search Words'].astype(str).str.replace(',', ';')
synonyms_df = synonyms_df.replace(['nan', np.nan], '') 
synonyms_df['Synonyms'] = (
    synonyms_df['Common Name(s)'].fillna('')
    .str.strip() + '; ' +
    synonyms_df['Scientific Name(s)'].fillna('')
    .str.strip() + '; ' +
    synonyms_df['Other Search Words'].fillna('')
    .str.strip()
)
synonyms_df.head()
# Out:
#     Ingredient                                     Common Name(s)  \
# 0  Ashwagandha         Ashwagandha; Indian Ginseng; Winter Cherry
# 1    Chamomile  Chamomile; English Chamomile; German Chamomile...
# 2         GABA                                               GABA
# 3      Glycine                                 Glycine; L-Glycine
# 4   Lemon Balm             Melissa; Balm Mint; Lemon Balm Extract
#
#                                   Scientific Name(s)  \
# 0                                 Withania somnifera
# 1  Matricaria chamomilla; Chamaemelum nobile; Mat...
# 2                            Gamma-Aminobutyric Acid
# 3                                   Aminoacetic Acid
# 4                                Melissa officinalis
#
#           Other Search Words  \
# 0  Withanolide; Withanolides
# 1
# 2
# 3
# 4
#
#                                             Synonyms
# 0  Ashwagandha; Indian Ginseng; Winter Cherry; Wi...
# 1  Chamomile; English Chamomile; German Chamomile...
# 2                    GABA; Gamma-Aminobutyric Acid;
# 3             Glycine; L-Glycine; Aminoacetic Acid;
# 4  Melissa; Balm Mint; Lemon Balm Extract; Meliss...

# %%
df_merged = df.merge(
    synonyms_df[['Ingredient', 'Synonyms']],  # only the columns we need
    left_on='Root Name',               # key in df
    right_on='Ingredient',             # key in synonyms_df
    how='left'                         # keep all rows from df
)

# Drop duplicate 'Ingredient' column
df = df_merged.drop(columns=['Ingredient'])
df.head()
# Out:
#             Root Name      PMID  \
# 0  Acetyl L-Carnitine  10022226
# 1  Acetyl L-Carnitine  10030388
# 2  Acetyl L-Carnitine  10036643
# 3  Acetyl L-Carnitine  10052020
# 4  Acetyl L-Carnitine  10067662
#
#                                                Title  \
# 0     Micronutrients prevent cancer and delay aging.
# 1  Significance of skeletal muscle properties on ...
# 2  Cellular dysmetabolism: the dark side of HIV-1...
# 3  Substrate utilization and work efficiency duri...
# 4  L-carnitine improves glucose disposal in type ...
#
#                                         Article Type  Publication Year  \
# 0  Journal Article; Research Support, Non-U.S. Go...              1998
# 1  Comparative Study; Journal Article; Research S...              1999
# 2                            Journal Article; Review              1996
# 3  Clinical Trial; Controlled Clinical Trial; Jou...              1999
# 4  Clinical Trial; Controlled Clinical Trial; Jou...              1999
#
#                                   PubMed URL Search Term(s)  \
# 0  https://pubmed.ncbi.nlm.nih.gov/10022226/      Carnitine
# 1  https://pubmed.ncbi.nlm.nih.gov/10030388/      Carnitine
# 2  https://pubmed.ncbi.nlm.nih.gov/10036643/      Carnitine
# 3  https://pubmed.ncbi.nlm.nih.gov/10052020/      Carnitine
# 4  https://pubmed.ncbi.nlm.nih.gov/10067662/      Carnitine
#
#                                             Synonyms
# 0  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 1  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 2  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 3  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 4  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...

# %% [markdown]
# # Defining Neuraci Type

# %%
# Define mapping of NeuraciTypes
priority_mapping = [
    (systematic_meta_analysis,'Systematic Review & Meta Analysis'), # 1st Priority
    (clinical_trial, 'Clinical Trials'),                            # 2nd Priority
    (observational_studies, 'Observational Studies & Reviews'),     # 3rd Priority

]

# Function to assign NeuraciType based on priority
def classify_type(type_list):
    for reference_list, category in priority_mapping:
        if any(item in reference_list for item in type_list):
            return category
    return 'Unclassified'  # optional, in case nothing matches

# Function to assign NeuraciType based on priority and return the matched item
# def classify_type(type_list):
#     for reference_list, category in priority_mapping:
#         for item in type_list:
#             if item in reference_list:
#                 return category, item  # Return both category and matched item
#     return 'Unclassified', None  # Default if nothing matches


# Create new column with a list of article types
df['Type_list'] = df['Article Type'].apply(lambda x: set([item.strip() for item in x.split(';')]))


# Apply function to create new column
#df['PubMedType'] = df['Type_list'].apply(lambda x: x.intersection(set(allowed_study_types)))
df['PubMedType'] = df['Type_list'].apply(
    lambda x: ', '.join(x.intersection(set(allowed_study_types))) if isinstance(x, set) else ''
)
df["NeuraciType"] = df['Type_list'].apply(lambda x: pd.Series(classify_type(x)))

df.head()
# Out:
#             Root Name      PMID  \
# 0  Acetyl L-Carnitine  10022226
# 1  Acetyl L-Carnitine  10030388
# 2  Acetyl L-Carnitine  10036643
# 3  Acetyl L-Carnitine  10052020
# 4  Acetyl L-Carnitine  10067662
#
#                                                Title  \
# 0     Micronutrients prevent cancer and delay aging.
# 1  Significance of skeletal muscle properties on ...
# 2  Cellular dysmetabolism: the dark side of HIV-1...
# 3  Substrate utilization and work efficiency duri...
# 4  L-carnitine improves glucose disposal in type ...
#
#                                         Article Type  Publication Year  \
# 0  Journal Article; Research Support, Non-U.S. Go...              1998
# 1  Comparative Study; Journal Article; Research S...              1999
# 2                            Journal Article; Review              1996
# 3  Clinical Trial; Controlled Clinical Trial; Jou...              1999
# 4  Clinical Trial; Controlled Clinical Trial; Jou...              1999
#
#                                   PubMed URL Search Term(s)  \
# 0  https://pubmed.ncbi.nlm.nih.gov/10022226/      Carnitine
# 1  https://pubmed.ncbi.nlm.nih.gov/10030388/      Carnitine
# 2  https://pubmed.ncbi.nlm.nih.gov/10036643/      Carnitine
# 3  https://pubmed.ncbi.nlm.nih.gov/10052020/      Carnitine
# 4  https://pubmed.ncbi.nlm.nih.gov/10067662/      Carnitine
#
#                                             Synonyms  \
# 0  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 1  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 2  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 3  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 4  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
#
#                                            Type_list  \
# 0  {Review, Journal Article, Research Support, No...
# 1  {Journal Article, Research Support, Non-U.S. G...
# 2                          {Review, Journal Article}
# 3  {Clinical Trial, Journal Article, Research Sup...
# 4  {Clinical Trial, Journal Article, Controlled C...
#
#                                   PubMedType                      NeuraciType
# 0                                     Review  Observational Studies & Reviews
# 1                          Comparative Study  Observational Studies & Reviews
# 2                                     Review  Observational Studies & Reviews
# 3  Clinical Trial, Controlled Clinical Trial                  Clinical Trials
# 4  Clinical Trial, Controlled Clinical Trial                  Clinical Trials

# %%
df[df['Root Name'] == 'Marjoram']
# Out:
#        Root Name      PMID                                              Title  \
# 138655  Marjoram  10519099  Comparison of continuous subcritical water ext...
# 138656  Marjoram  10960901  Evaluation of massage with essential oils on c...
# 138657  Marjoram  11929287  Recovery of pigments from Origanum majorana L....
# 138658  Marjoram  12153923  Comparison of agreement between different meas...
# 138659  Marjoram  12153924  Comparison of acceptability of and preferences...
# ...          ...       ...                                                ...
# 138749  Marjoram   7238011  Perioral dermatitis from marjoram, bay leaf an...
# 138750  Marjoram   7483863  Effect of irradiation on the microbiological s...
# 138751  Marjoram   8150290  Pairwise comparisons of mitochondrial DNA sequ...
# 138752  Marjoram   8318863  Microbiological screening method for indicatio...
# 138753  Marjoram   8630713  Labiatae allergy: systemic reactions due to in...
#
#                                              Article Type  Publication Year  \
# 138655  Comparative Study; Journal Article; Research S...              1999
# 138656  Clinical Trial; Journal Article; Randomized Co...              2000
# 138657  Comparative Study; Journal Article; Research S...              2002
# 138658  Clinical Trial; Comparative Study; Journal Art...              2002
# 138659  Comparative Study; Journal Article; Multicente...              2002
# ...                                                   ...               ...
# 138749                      Case Reports; Journal Article              1981
# 138750                 Comparative Study; Journal Article              1995
# 138751  Comparative Study; Journal Article; Research S...              1994
# 138752  Comparative Study; Journal Article; Research S...              1993
# 138753                      Case Reports; Journal Article              1996
#
#                                        PubMed URL  \
# 138655  https://pubmed.ncbi.nlm.nih.gov/10519099/
# 138656  https://pubmed.ncbi.nlm.nih.gov/10960901/
# 138657  https://pubmed.ncbi.nlm.nih.gov/11929287/
# 138658  https://pubmed.ncbi.nlm.nih.gov/12153923/
# 138659  https://pubmed.ncbi.nlm.nih.gov/12153924/
# ...                                           ...
# 138749   https://pubmed.ncbi.nlm.nih.gov/7238011/
# 138750   https://pubmed.ncbi.nlm.nih.gov/7483863/
# 138751   https://pubmed.ncbi.nlm.nih.gov/8150290/
# 138752   https://pubmed.ncbi.nlm.nih.gov/8318863/
# 138753   https://pubmed.ncbi.nlm.nih.gov/8630713/
#
#                      Search Term(s)                       Synonyms  \
# 138655                     Marjoram  Marjoram; Origanum majorana;
# 138656                     Marjoram  Marjoram; Origanum majorana;
# 138657  Marjoram; Origanum majorana  Marjoram; Origanum majorana;
# 138658                     Marjoram  Marjoram; Origanum majorana;
# 138659                     Marjoram  Marjoram; Origanum majorana;
# ...                             ...                            ...
# 138749                     Marjoram  Marjoram; Origanum majorana;
# 138750                     Marjoram  Marjoram; Origanum majorana;
# 138751                     Marjoram  Marjoram; Origanum majorana;
# 138752                     Marjoram  Marjoram; Origanum majorana;
# 138753  Marjoram; Origanum majorana  Marjoram; Origanum majorana;
#
#                                                 Type_list  \
# 138655  {Journal Article, Research Support, Non-U.S. G...
# 138656  {Clinical Trial, Journal Article, Randomized C...
# 138657  {Journal Article, Research Support, Non-U.S. G...
# 138658  {Randomized Controlled Trial, Comparative Stud...
# 138659  {Multicenter Study, Journal Article, Research ...
# ...                                                   ...
# 138749                    {Journal Article, Case Reports}
# 138750               {Journal Article, Comparative Study}
# 138751  {Journal Article, Research Support, Non-U.S. G...
# 138752  {Journal Article, Research Support, Non-U.S. G...
# 138753                    {Journal Article, Case Reports}
#
#                                                PubMedType  \
# 138655                                  Comparative Study
# 138656        Clinical Trial, Randomized Controlled Trial
# 138657                                  Comparative Study
# 138658  Multicenter Study, Comparative Study, Clinical...
# 138659               Multicenter Study, Comparative Study
# ...                                                   ...
# 138749                                       Case Reports
# 138750                                  Comparative Study
# 138751                                  Comparative Study
# 138752                                  Comparative Study
# 138753                                       Case Reports
#
#                             NeuraciType
# 138655  Observational Studies & Reviews
# 138656                  Clinical Trials
# 138657  Observational Studies & Reviews
# 138658                  Clinical Trials
# 138659                  Clinical Trials
# ...                                 ...
# 138749  Observational Studies & Reviews
# 138750  Observational Studies & Reviews
# 138751  Observational Studies & Reviews
# 138752  Observational Studies & Reviews
# 138753  Observational Studies & Reviews
#
# [99 rows x 11 columns]

# %%
df.groupby('Root Name')['Root Name'].count().sort_values(ascending=True)[:50]
# Out:
# Root Name
# White Musk                        2
# Muira Puama                       7
# Yuzu                             22
# Osmanthus                        22
# Hinoki Cypress                   25
# Clary Sage                       30
# Vetiver                          40
# Ylang Ylang                      46
# Patchouli                        63
# Damask Rose                      78
# Hericium mushroom                81
# Sandalwood                       87
# Cardamom                         90
# Damiana                          94
# Cardamon                         95
# Cedarwood                        97
# Marjoram                         99
# Myrrh                           101
# Frankincense                    102
# Geranium                        127
# Bergamot                        147
# Neroli                          169
# Ergothioneine                   170
# Bitter Orange                   195
# Vanilla                         236
# Rhodiola                        270
# Theanine                        279
# Sweet Almond Oil                280
# Black Pepper                    285
# Jasmine                         330
# Bacopa Monnieri                 335
# Maca                            352
# Black Cohosh                    353
# Nicotinamide mononucleotide     377
# Valerian                        385
# Lemon Balm                      400
# Juniper                         404
# Clove Oil/Bud                   414
# Red Clover                      491
# Citicoline                      519
# Ashwagandha                     520
# Peppermint                      571
# Eucalyptus                      785
# Cinnamon                        798
# Rosemary                        897
# Basil                           906
# Chamomile                       958
# Magnolia                       1026
# Lavender                       1137
# Holy Basil                     1166
# Name: Root Name, dtype: int64

# %%
ingredients = ["Cedarwood","Marjoram"]

# %%
no_abstract_pmids = [
    16942582,
    18349580,
    18781101,
    19901509,
    27333653,
    27788889,
    9536426
]

none_pmids = [
    23652808,
    25163405,
    25704097,
    26165898,
    28117719,
    28460831,
    28895508,
    29543548,
    30541521,
    31618733,
    32037737,
    32407947,
    32439404,
    35917731
]

# %%
from UPDATED_meta_data_generation import process_pmids

#ingredient_df = df[df['Root Name'].isin([10473175])]
ingredient_df = df[df['Root Name'].isin(ingredients)]
#ingredient_df = df[(df['Root Name'].isin(ingredients)) & (df['NeuraciType'] == 'Clinical Trials')]
#ingredient_df = df[(df['Root Name'].isin(ingredients)) & (df['PMID'].isin([28670915,32407947]))][:2]
process_pmids(ingredient_df['Root Name'],ingredient_df['Search Term(s)'],ingredient_df['Synonyms'],ingredient_df['PMID'], ingredient_df['PubMedType'],output_file="output/cedarwood_Marjoram_10|10.json")
# Out:
# Processing PMIDs:   0%|          | 0/196 [00:00<?, ?pmid/s]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: {'Cedrus'}
# >>>>>>>>>>Focus False
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   1%|          | 1/196 [00:08<27:39,  8.51s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: {'Cedrus'}
# >>>>>>>>>>Focus False
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   1%|          | 2/196 [00:14<23:35,  7.30s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: {'Cedrus'}
# >>>>>>>>>>Focus False
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   2%|▏         | 3/196 [00:23<25:32,  7.94s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: set()
# >>>>>>>>>>Focus True
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   2%|▏         | 4/196 [00:31<25:27,  7.95s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: set()
# >>>>>>>>>>Focus True
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   3%|▎         | 5/196 [00:39<25:21,  7.97s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: {'Cedrus'}
# >>>>>>>>>>Focus False
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   3%|▎         | 6/196 [00:45<22:42,  7.17s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: {'Cedrus'}
# >>>>>>>>>>Focus False
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   4%|▎         | 7/196 [00:52<22:31,  7.15s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: {'Cedrus'}
# >>>>>>>>>>Focus False
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   4%|▍         | 8/196 [00:57<20:53,  6.67s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: {'Cedrus'}
# >>>>>>>>>>Focus False
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   5%|▍         | 9/196 [01:02<18:50,  6.05s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: set()
# >>>>>>>>>>Focus True
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   5%|▌         | 10/196 [01:08<18:47,  6.06s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: {'Cedarwood'}
# >>>>>>>>>>Focus False
# >>>>>Schema: {'type': 'object', 'properties': {'duration_days': {'oneOf': [{'type': 'integer', 'description': 'Study or treatment duration expressed in days. Convert weeks/months/years to total days.'}, {'const': 'not mentioned', 'description': 'Duration information was not reported or cannot be determined from the text.'}], 'description': 'Duration of the study or experimental intervention, normalized to days.'}, 'sample_size': {'oneOf': [{'type': 'integer', 'description': 'Number of participants included in the study.'}, {'const': 'not mentioned', 'description': 'The sample size was not reported or cannot be determined from the study.'}], 'description': 'Total number of participants or samples in the study.'}, 'sample_gender': {'type': 'array', 'items': {'oneOf': [{'const': 'male', 'description': 'Participant identified as male.'}, {'const': 'female', 'description': 'Participant identified as female.'}, {'const': 'other', 'description': 'Participant gender is not male or female (includes nonbinary or diverse identities).'}, {'const': 'not mentioned', 'description': 'Gender information was not provided or not stated in the source.'}]}, 'description': 'Participant genders included in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'species': {'type': 'array', 'items': {'oneOf': [{'const': 'humans', 'description': 'Studies involving human participants, volunteers, or patients.'}, {'const': 'animals', 'description': 'Studies involving non-human animals such as mice, rats, rabbits, or other vertebrates/invertebrates.'}, {'const': 'cell lines', 'description': 'Immortalized or continuously cultured cells derived from humans or animals, used for in vitro experiments.'}, {'const': 'primary cells', 'description': 'Cells directly isolated from tissues of humans, animals, or plants, cultured briefly for experiments.'}, {'const': 'tissues', 'description': 'Ex vivo samples of tissues from humans, animals, or plants used in experiments or analysis.'}, {'const': 'organoids', 'description': '3D miniaturized and simplified versions of organs grown in vitro from stem cells to model organ function or disease.'}, {'const': 'microorganisms', 'description': 'Microscopic organisms including bacteria, fungi, protozoa, algae, or viruses.'}, {'const': 'plants', 'description': 'Whole plants or plant parts (leaves, roots, seeds, etc.) used in experiments or studies.'}, {'const': 'computer models', 'description': 'Computational or in silico models, simulations, or algorithmic experiments.'}, {'const': 'other', 'description': 'Any experimental system or species that does not fall into the predefined categories.'}, {'const': 'not mentioned', 'description': 'Species or biological system was not specified in the article.'}]}, 'description': 'Species or biological systems studied in the article.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'experimental_model': {'type': 'array', 'items': {'oneOf': [{'const': 'in vitro', 'description': 'Experiments conducted outside living organisms, typically in test tubes, culture plates, or petri dishes.'}, {'const': 'ex vivo', 'description': 'Experiments conducted on tissues taken from living organisms but outside the organism.'}, {'const': 'in vivo', 'description': 'Experiments conducted within living organisms (humans, animals, or plants).'}, {'const': 'in silico', 'description': 'Studies conducted using computer simulations, computational modeling, or digital analyses.'}, {'const': 'other', 'description': 'Any experimental approach or environment not covered by the above categories like ex vivo, in vivo etc.'}, {'const': 'not mentioned', 'description': 'The experimental model type was not reported.'}]}, 'description': 'Type(s) of experimental models used in the study.', 'minItems': 1, 'uniqueItems': True, 'default': ['not mentioned']}, 'population': {'oneOf': [{'type': 'string', 'description': 'Short descriptive text of the study population, including condition/dia ...
# Processing PMIDs:   6%|▌         | 11/196 [01:14<18:07,  5.88s/pmid]
# Synonyms Cedarwood; Cedrus; Cedar wood;Cedar-wood
# >>>>>> Synonyms List ['Cedarwood', 'Cedrus', 'Cedar wood', 'Cedar-wood']
# >>>>>Found Synonyms: {'Cedar-wood'}
# >>>>>>>>>>Focus False
# ...
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'nf-kappab',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'mapk/p38',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'tnf-alpha/il-1beta',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'pi3k/akt',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'cell growth',
#      'domain': 'function',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'proliferation',
#      'domain': 'function',
#      'type': 'secondary',
#      'result': 'improved'}],
#    'diseases': ['breast cancer'],
#    'symptoms': [],
#    'keywords': ['marjoram',
#     'thyme',
#     'persimmon',
#     'phytochemicals',
#     'breast cancer',
#     'anticarcinogenic',
#     'nutraceuticals'],
#    'location': None,
#    'mechanism': ['nf-kappab', 'mapk/p38', 'tnf-alpha/il-1beta', 'pi3k/akt']}},
#  {'root_name': 'Marjoram',
#   'search_term': 'Marjoram',
#   'synonyms': 'Marjoram; Origanum majorana; ',
#   'PMID': 39956033,
#   'pubmed_type': 'Randomized Controlled Trial, Veterinary',
#   'metadata': {'duration_days': 21,
#    'sample_size': 150,
#    'sample_gender': ['not mentioned'],
#    'species': ['animals'],
#    'experimental_model': ['in vivo'],
#    'population': 'landrace x large white sows (parity 1-9)',
#    'study_type': ['randomized controlled trial'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'marjoram',
#      'daily_dosage': 300,
#      'units': 'ml',
#      'original_text': '300 ml of phytotherapeutic agent (phytotherapeutic)'}],
#    'usage': ['other'],
#    'conditions': ['endometritis', 'postpartum dysgalactiae syndrome'],
#    'biomarkers': ['uterine diameter'],
#    'functions': ['not mentioned'],
#    'purpose': 'to evaluate the influence of the intrauterine application of a phytotherapeutic agent after farrowing on uterine involution in sows.',
#    'conclusion': 'a single postpartal intrauterine application of a phytotherapeutic agent demonstrated no significant impact on uterine involution, while sow-specific and management factors remained pivotal.',
#    'outcomes': [{'name': 'endometritis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'postpartum dysgalactiae syndrome',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'uterine diameter',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'no_effect'}],
#    'diseases': ['endometritis', 'postpartum dysgalactiae syndrome'],
#    'symptoms': [],
#    'keywords': ['phytotherapeutic agent',
#     'uterine involution',
#     'sows',
#     'postpartum disorders'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Marjoram',
#   'search_term': 'Marjoram',
#   'synonyms': 'Marjoram; Origanum majorana; ',
#   'PMID': 40142079,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['antioxidant capacity', 'antimicrobial activity'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to provide an overview of the antioxidant capacity, antimicrobial activity, and major applications of aromatic herbs.',
#    'conclusion': 'aromatic herbs like marjoram possess high levels of bioactive phytochemicals, particularly rich in phenolic acids, flavones, phenolic diterpenes, and flavanones, with various beneficial effects.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['aromatic herbs',
#     'bioactive compounds',
#     'antioxidant capacity',
#     'antimicrobial activity',
#     'lamiaceae family',
#     'phenolic acids',
#     'flavones',
#     'phenolic diterpenes',
#     'flavanones'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Marjoram',
#   'search_term': 'Marjoram',
#   'synonyms': 'Marjoram; Origanum majorana; ',
#   'PMID': 40830630,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['not mentioned'],
#    'population': 'egyptian sweet marjoram leaves',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': ['equilibrium moisture content',
#     'effective moisture diffusivity',
#     'activation energy'],
#    'functions': [],
#    'purpose': 'to examine the drying characteristics of egyptian sweet marjoram leaves using a hybrid solar drying system and compare it with conventional oven drying.',
#    'conclusion': 'the study demonstrated the effectiveness and sustainability of hybrid solar drying for preserving the quality and functional properties of medicinal and aromatic herbs like marjoram.',
#    'outcomes': [{'name': 'equilibrium moisture content',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'effective moisture diffusivity',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'activation energy',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['drying kinetics',
#     'diffusivity',
#     'thermodynamic properties',
#     'hybrid solar drying',
#     'oven drying',
#     'egyptian sweet marjoram'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Marjoram',
#   'search_term': 'Marjoram; Origanum majorana',
#   'synonyms': 'Marjoram; Origanum majorana; ',
#   'PMID': 40998983,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['in vivo'],
#    'population': 'origanum majorana plants cultivated under different nutrient management strategies',
#    'study_type': ['randomized controlled trial'],
#    'focus': ['primary'],
#    'benefits': ['improved plant growth', 'enhanced essential oil yield'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'origanum majorana',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'irrigated with water of different qualities at two cuts'}],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': ['total phenolic content',
#     'soil bulk density',
#     'potassium content',
#     'electroconductivity'],
#    'functions': ['plant growth',
#     'essential oil yield',
#     'essential oil composition'],
#    'purpose': 'to assess and compare plant morphometric characteristics, essential oil yield, and composition of origanum majorana irrigated with water of different qualities',
#    'conclusion': 'irrigating origanum majorana with hydroponic solutions enhances plant growth, essential oil yield, and composition, while biofloc wastewater could be a feasible alternative for organic production.',
#    'outcomes': [{'name': 'plant growth',
#      'domain': 'function',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'essential oil yield',
#      'domain': 'function',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'essential oil composition',
#      'domain': 'function',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'total phenolic content',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'soil bulk density',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'potassium content',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'electroconductivity',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['origanum majorana',
#     'essential oil yield',
#     'plant growth',
#     'sustainable organic nutrient management',
#     'hydroponic solutions',
#     'biofloc wastewater'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Marjoram',
#   'search_term': 'Marjoram',
#   'synonyms': 'Marjoram; Origanum majorana; ',
#   'PMID': 7483863,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['in vitro'],
#    'population': 'spices from egyptian local markets',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'marjoram',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'irradiation with different recommended doses (0, 5, 10, 20 and 30 kgy)'}],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': ['total aerobic bacterial content',
#     'total contents of moulds'],
#    'functions': [],
#    'purpose': 'to study the effect of irradiation on the microbiological status and flavouring materials of selected spices.',
#    'conclusion': 'irradiation at 10 kgy is a sufficiently high dose to eliminate the micro-organisms in spices, causing only slight changes in the flavouring materials.',
#    'outcomes': [{'name': 'total aerobic bacterial content',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'total contents of moulds',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['irradiation',
#     'microbiological status',
#     'flavouring materials',
#     'spices',
#     'marjoram',
#     'ginger',
#     'hot pepper'],
#    'location': 'egypt',
#    'mechanism': ['conversion of terpenes to monoterpenesalcohols']}},
#  {'root_name': 'Marjoram',
#   'search_term': 'Marjoram',
#   'synonyms': 'Marjoram; Origanum majorana; ',
#   'PMID': 8150290,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': 'none',
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to consider the effect on the distribution of pairwise differences between mitochondrial dna sequences in human populations with constant population size and geographic subdivision.',
#    'conclusion': 'population genetics models currently used to analyze mitochondrial dna data may fail to reflect important features of human mitochondrial dna evolution, such as selection on the mitochondrial genome or special population dynamics.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['mitochondrial dna',
#     'population genetics',
#     'human evolution',
#     'geographic subdivision',
#     'mutation mechanisms'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Marjoram',
#   'search_term': 'Marjoram',
#   'synonyms': 'Marjoram; Origanum majorana; ',
#   'PMID': 8318863,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 192,
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['in vitro'],
#    'population': 'spices and herbs including whole allspice, whole and powdered black peppers, whole white pepper, paprika powder, cut basil, cut marjoram, and crushed cardamom',
#    'study_type': ['other'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'marjoram',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'irradiated with doses of 0, 5, and 10 kgy'}],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to evaluate a microbiological screening method for detecting irradiation of spices and herbs using deft and apc methods',
#    'conclusion': 'the study demonstrated that the microbiological screening method using deft and apc can effectively differentiate between irradiated and nonirradiated spices and herbs, with acceptable variability among laboratories.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['irradiation',
#     'spices',
#     'herbs',
#     'microbiological screening',
#     'deft',
#     'apc',
#     'collaborative study'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Marjoram',
#   'search_term': 'Marjoram; Origanum majorana',
#   'synonyms': 'Marjoram; Origanum majorana; ',
#   'PMID': 8630713,
#   'pubmed_type': 'Case Reports',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 1,
#    'sample_gender': ['not mentioned'],
#    'species': ['humans'],
#    'experimental_model': ['in vivo', 'in vitro'],
#    'population': 'patient with systemic allergic reactions to oregano and thyme',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['systemic allergic reactions'],
#    'interventions': [{'ingredient': 'oregano',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'ingestion of oregano'},
#     {'ingredient': 'thyme',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'ingestion of thyme'}],
#    'usage': ['ingestion'],
#    'conditions': ['systemic allergic reactions'],
#    'biomarkers': ['total serum ige', 'specific ige'],
#    'functions': [],
#    'purpose': 'to describe systemic allergic reactions caused by oregano and thyme in a patient',
#    'conclusion': 'plants belonging to the labiatae family, including oregano and thyme, seem to show cross-sensitivity based on clinical history and test results.',
#    'outcomes': [{'name': 'systemic allergic reactions',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'total serum ige',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': 'specific ige',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['labiatae allergy',
#     'systemic reactions',
#     'oregano',
#     'thyme',
#     'cross-sensitivity',
#     'ige'],
#    'location': None,
#    'mechanism': ['cross-sensitivity']}}]

# %% [markdown]
# # Enriching Data

# %%
import json

ingredient_df_lookup = ingredient_df.set_index(["PMID",'Root Name'])[["Publication Year","NeuraciType","Synonyms","PubMed URL"]].to_dict(orient="index")


# Read JSON file
with open("output/cedarwood_Marjoram_10|10.json", "r", encoding="utf-8") as f:
    json_list = json.load(f)

# Add attributes 
for record in json_list:
    pmid = record["PMID"]
    root_name = record['root_name']
    key = (pmid,root_name)
    if key in ingredient_df_lookup:
        lookup_data = ingredient_df_lookup[key]
        record.setdefault("metadata", {})  # ensure "metadata" exists
        record["metadata"]["published_year"] = lookup_data["Publication Year"]
        record["metadata"]["neuraci_type"] = lookup_data["NeuraciType"]
        #record["metadata"]["synonyms"] = lookup_data["Synonyms"]
        record["metadata"]["url"] = lookup_data["PubMed URL"]

# Save JSON file
with open("output/cedarwood_Marjoram_enriched.json", "w", encoding="utf-8") as f:
    json.dump(json_list, f, indent=2, ensure_ascii=False)

# %% [markdown]
# # Converting into Structured Data

# %%
import json
import pandas as pd

# # --- Step 1: Load JSON file ---
# with open("data.json", "r", encoding="utf-8") as f:
#     records = json.load(f)   # assuming it's a list of JSON objects

rows = []
records = json_list
# --- Step 2: Flatten each record ---
for rec in records:
    pmid = rec.get("PMID")
    root_name = rec.get("root_name")
    search_term = rec.get("search_term")
    meta = rec.get("metadata", {})
    pubmed_type = rec.get("pubmed_type")
    synonyms = rec.get('synonyms')

    row = {
        "root_name":root_name,
        "Search Term(s)":search_term,
        "PMID": pmid,
        "synonyms":synonyms,
        "experimental_model":meta.get("experimental_model"),
        "published_year": meta.get("published_year"),
        "neuraci_type": meta.get("neuraci_type"),
        "pubmed_type":pubmed_type,
        "study_type": ";".join(meta.get('study_type')),
        "duration_days": meta.get("duration_days"),
        "sample_size": meta.get("sample_size"),
        "sample_gender": ";".join(meta.get("sample_gender", [])),
        "species": ";".join(meta.get("species", [])),
        "population": meta.get("population"),
        "purpose": meta.get("purpose"),
        "focus": "".join(meta.get("focus")),
        "benefits": ";".join(meta.get("benefits", [])),
        "synergies_interactions_positive": ";".join(meta.get("synergies_interactions_positive", [])),
        "synergies_interactions_negative": ";".join(meta.get("synergies_interactions_negative", [])),
        "safety_side_effects": ";".join(meta.get("safety_side_effects", [])),
        "conditions": ";".join(meta.get("conditions", [])),
        "biomarkers": ";".join(meta.get("biomarkers", [])),
        "symptoms": ";".join(meta.get("symptoms", [])),
        "keywords": ";".join(meta.get("keywords", [])),
        "diseases": ";".join(meta.get("diseases", [])),
        "mechanism": ";".join(meta.get("mechanism", [])),
        "usage": ";".join(meta.get("usage", [])),
        "conclusion":meta.get("conclusion"),
        "url": meta.get("url", []),
    }

    # --- Expand interventions ---
    for i, iv in enumerate(meta.get("interventions", []), start=1):
        row[f"intervention{i}_ingredient"] = iv.get("ingredient")
        row[f"intervention{i}_daily_dosage"] = iv.get("daily_dosage")
        row[f"intervention{i}_units"] = iv.get("units")
        row[f"intervention{i}_original_text"] = iv.get("original_text")

    # --- Expand outcomes ---
    for j, oc in enumerate(meta.get("outcomes", []), start=1):
        row[f"outcome{j}_name"] = oc.get("name")
        row[f"outcome{j}_domain"] = oc.get("domain")
        row[f"outcome{j}_type"] = oc.get("type")
        row[f"outcome{j}_result"] = oc.get("result")

    rows.append(row)

# --- Step 3: Convert to DataFrame ---
output_df = pd.DataFrame(rows)

# --- Step 4: Save to CSV ---
output_df.to_csv("output/cedarwood_Marjoram_10|10.csv", index=False)
output_df.head()
# Out:
#    root_name Search Term(s)      PMID  \
# 0  Cedarwood         Cedrus  10473175
# 1  Cedarwood         Cedrus  11524119
# 2  Cedarwood         Cedrus  11876259
# 3  Cedarwood         Cedrus  11876600
# 4  Cedarwood         Cedrus  11896972
#
#                                    synonyms experimental_model  \
# 0  Cedarwood; Cedrus; Cedar wood;Cedar-wood         [in vitro]
# 1  Cedarwood; Cedrus; Cedar wood;Cedar-wood         [in vitro]
# 2  Cedarwood; Cedrus; Cedar wood;Cedar-wood    [not mentioned]
# 3  Cedarwood; Cedrus; Cedar wood;Cedar-wood          [in vivo]
# 4  Cedarwood; Cedrus; Cedar wood;Cedar-wood          [in vivo]
#
#    published_year                     neuraci_type  \
# 0            1999  Observational Studies & Reviews
# 1            2001  Observational Studies & Reviews
# 2            2002  Observational Studies & Reviews
# 3            2002                  Clinical Trials
# 4            2002  Observational Studies & Reviews
#
#                                  pubmed_type     study_type  duration_days  \
# 0                          Comparative Study  not mentioned  not mentioned
# 1                          Comparative Study  not mentioned  not mentioned
# 2                  Review, Comparative Study  not mentioned  not mentioned
# 3  Clinical Trial, Controlled Clinical Trial  not mentioned            730
# 4                               Case Reports  not mentioned  not mentioned
#
#    ... outcome17_type outcome17_result outcome18_name outcome18_domain  \
# 0  ...            NaN              NaN            NaN              NaN
# 1  ...            NaN              NaN            NaN              NaN
# 2  ...            NaN              NaN            NaN              NaN
# 3  ...            NaN              NaN            NaN              NaN
# 4  ...            NaN              NaN            NaN              NaN
#
#   outcome18_type outcome18_result intervention6_ingredient  \
# 0            NaN              NaN                      NaN
# 1            NaN              NaN                      NaN
# 2            NaN              NaN                      NaN
# 3            NaN              NaN                      NaN
# 4            NaN              NaN                      NaN
#
#   intervention6_daily_dosage intervention6_units intervention6_original_text
# 0                        NaN                 NaN                         NaN
# 1                        NaN                 NaN                         NaN
# 2                        NaN                 NaN                         NaN
# 3                        NaN                 NaN                         NaN
# 4                        NaN                 NaN                         NaN
#
# [5 rows x 125 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
output_df.head()
# Out:
#    root_name Search Term(s)      PMID  \
# 0  Cedarwood         Cedrus  10473175
# 1  Cedarwood         Cedrus  11524119
# 2  Cedarwood         Cedrus  11876259
# 3  Cedarwood         Cedrus  11876600
# 4  Cedarwood         Cedrus  11896972
#
#                                    synonyms experimental_model  \
# 0  Cedarwood; Cedrus; Cedar wood;Cedar-wood         [in vitro]
# 1  Cedarwood; Cedrus; Cedar wood;Cedar-wood         [in vitro]
# 2  Cedarwood; Cedrus; Cedar wood;Cedar-wood    [not mentioned]
# 3  Cedarwood; Cedrus; Cedar wood;Cedar-wood          [in vivo]
# 4  Cedarwood; Cedrus; Cedar wood;Cedar-wood          [in vivo]
#
#    published_year                     neuraci_type  \
# 0            1999  Observational Studies & Reviews
# 1            2001  Observational Studies & Reviews
# 2            2002  Observational Studies & Reviews
# 3            2002                  Clinical Trials
# 4            2002  Observational Studies & Reviews
#
#                                  pubmed_type     study_type  duration_days  \
# 0                          Comparative Study  not mentioned  not mentioned
# 1                          Comparative Study  not mentioned  not mentioned
# 2                  Review, Comparative Study  not mentioned  not mentioned
# 3  Clinical Trial, Controlled Clinical Trial  not mentioned            730
# 4                               Case Reports  not mentioned  not mentioned
#
#      sample_size  sample_gender                species  \
# 0  not mentioned  not mentioned  microorganisms;plants
# 1            137  not mentioned                 plants
# 2  not mentioned  not mentioned                 plants
# 3             23  not mentioned                 humans
# 4              3  not mentioned                animals
#
#                                           population  \
# 0  plants used in folk medicine for gastric ailme...
# 1                                        gymnosperms
# 2  abietoid seed fatty acid compositions of the g...
# 3            patients with japanese cedar pollinosis
# 4  dogs with recurrent pruritic dermatitis during...
#
#                                              purpose      focus  \
# 0  to study the anti-helicobacter pylori effect o...  secondary
# 1  to determine the fatty acid composition of pho...  secondary
# 2  to review the seed fatty acid compositions of ...  secondary
# 3  to evaluate the effect of japanese cedar-speci...       none
# 4  to investigate the sensitivity of dogs to japa...       none
#
#                             benefits synergies_interactions_positive  \
# 0  anti-helicobacter pylori activity                   not mentioned
# 1                      not mentioned                   not mentioned
# 2                      not mentioned                   not mentioned
# 3  reduced symptom-medication scores                   not mentioned
# 4                      not mentioned                   not mentioned
#
#   synergies_interactions_negative safety_side_effects  \
# 0                   not mentioned       not mentioned
# 1                   not mentioned       not mentioned
# 2                   not mentioned       not mentioned
# 3                   not mentioned       not mentioned
# 4                   not mentioned       not mentioned
#
#                    conditions  \
# 0               peptic ulcers
# 1
# 2
# 3   japanese cedar pollinosis
# 4  seasonal atopic dermatitis
#
#                                           biomarkers             symptoms  \
# 0                                      not mentioned
# 1  fatty acid composition;chloroplastic lipids;di...
# 2  delta5-olefinic acids;taxoleic acid;pinolenic ...
# 3                          il-4;il-5;il-13;ifn-gamma
# 4    ige specific to cry j 1;ige specific to cry j 2  pruritic dermatitis
#
#                                             keywords           diseases  \
# 0  anti-helicobacter pylori;turkish plants;folk m...       peptic ulcer
# 1  gymnosperms;fatty acid composition;taxonomic r...
# 2  abietoid;seed fatty acid;delta5-olefinic acids...
# 3  japanese cedar;immunotherapy;cytokine producti...  allergic rhinitis
# 4  japanese cedar pollen;atopic dermatitis;ige;cr...  atopic dermatitis
#
#                           mechanism          usage  \
# 0                                    not mentioned
# 1                                    not mentioned
# 2                                    not mentioned
# 3  cytokine expression modification  not mentioned
# 4           type i hypersensitivity  not mentioned
#
#                                           conclusion  \
# 0  the study found that extracts from six of the ...
# 1  a clear-cut separation of the genera abies, la...
# 2  the study suggests that tsuga spp. and hespero...
# 3  specific immunotherapy for japanese cedar poll...
# 4  cry j 1 was identified as the major allergen r...
#
#                                          url intervention1_ingredient  \
# 0  https://pubmed.ncbi.nlm.nih.gov/10473175/            cedrus libani
# 1  https://pubmed.ncbi.nlm.nih.gov/11524119/                      NaN
# 2  https://pubmed.ncbi.nlm.nih.gov/11876259/                      NaN
# 3  https://pubmed.ncbi.nlm.nih.gov/11876600/                   cs-560
# 4  https://pubmed.ncbi.nlm.nih.gov/11896972/    japanese cedar pollen
#
#    intervention1_daily_dosage intervention1_units  \
# 0                         NaN
# 1                         NaN                 NaN
# 2                         NaN                 NaN
# 3                         NaN
# 4                         NaN
#
#                          intervention1_original_text  \
# 0                             cones of cedrus libani
# 1                                                NaN
# 2                                                NaN
# 3                                             cs-560
# 4  sensitive to cj pollen allergen using intrader...
#
#                 outcome1_name outcome1_domain outcome1_type outcome1_result  \
# 0               peptic ulcers       condition       primary    not_reported
# 1      fatty acid composition       biomarker       primary    not_reported
# 2       delta5-olefinic acids       biomarker     secondary    not_reported
# 3   japanese cedar pollinosis       condition       primary        improved
# 4  seasonal atopic dermatitis       condition       primary        improved
#
#              outcome2_name outcome2_domain outcome2_type outcome2_result  \
# 0                      NaN             NaN           NaN             NaN
# 1     chloroplastic lipids       biomarker     secondary    not_reported
# 2            taxoleic acid       biomarker     secondary    not_reported
# 3                     il-4       biomarker       primary        improved
# 4  ige specific to cry j 1       biomarker       primary        improved
#
#                 outcome3_name outcome3_domain outcome3_type outcome3_result  \
# 0                         NaN             NaN           NaN             NaN
# 1  digalactosyldiacylglycerol       biomarker     secondary    not_reported
# 2              pinolenic acid       biomarker     secondary    not_reported
# 3                        il-5       biomarker       primary        improved
# 4     ige specific to cry j 2       biomarker     secondary       no_effect
#
#                   outcome4_name outcome4_domain outcome4_type outcome4_result  \
# 0                           NaN             NaN           NaN             NaN
# 1  monogalactosyldiacylglycerol       biomarker     secondary    not_reported
# 2              coniferonic acid       biomarker     secondary    not_reported
# 3                         il-13       biomarker       primary        improved
# 4               immune response        function       primary        improved
#
#        outcome5_name outcome5_domain outcome5_type outcome5_result  \
# 0                NaN             NaN           NaN             NaN
# 1                NaN             NaN           NaN             NaN
# 2  keteleeronic acid       biomarker     secondary    not_reported
# 3          ifn-gamma       biomarker       primary       no_effect
# 4                NaN             NaN           NaN             NaN
#
#          outcome6_name outcome6_domain outcome6_type outcome6_result  \
# 0                  NaN             NaN           NaN             NaN
# 1                  NaN             NaN           NaN             NaN
# 2       sciadonic acid       biomarker     secondary    not_reported
# 3  cytokine production        function       primary        improved
# 4                  NaN             NaN           NaN             NaN
#
#                  outcome7_name outcome7_domain outcome7_type outcome7_result  \
# 0                          NaN             NaN           NaN             NaN
# 1                          NaN             NaN           NaN             NaN
# 2  14-methyl hexadecanoic acid       biomarker     secondary    not_reported
# 3                          NaN             NaN           NaN             NaN
# 4                          NaN             NaN           NaN             NaN
#
#   intervention2_ingredient  intervention2_daily_dosage intervention2_units  \
# 0                      NaN                         NaN                 NaN
# 1                      NaN                         NaN                 NaN
# 2                      NaN                         NaN                 NaN
# 3                      NaN                         NaN                 NaN
# 4                      NaN                         NaN                 NaN
#
#   intervention2_original_text outcome8_name outcome8_domain outcome8_type  \
# 0                         NaN           NaN             NaN           NaN
# 1                         NaN           NaN             NaN           NaN
# 2                         NaN           NaN             NaN           NaN
# 3                         NaN           NaN             NaN           NaN
# 4                         NaN           NaN             NaN           NaN
#
#   outcome8_result outcome9_name outcome9_domain outcome9_type outcome9_result  \
# 0             NaN           NaN             NaN           NaN             NaN
# 1             NaN           NaN             NaN           NaN             NaN
# 2             NaN           NaN             NaN           NaN             NaN
# 3             NaN           NaN             NaN           NaN             NaN
# 4             NaN           NaN             NaN           NaN             NaN
#
#   intervention3_ingredient  intervention3_daily_dosage intervention3_units  \
# 0                      NaN                         NaN                 NaN
# 1                      NaN                         NaN                 NaN
# 2                      NaN                         NaN                 NaN
# 3                      NaN                         NaN                 NaN
# 4                      NaN                         NaN                 NaN
#
#   intervention3_original_text intervention4_ingredient  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
#
#    intervention4_daily_dosage intervention4_units intervention4_original_text  \
# 0                         NaN                 NaN                         NaN
# 1                         NaN                 NaN                         NaN
# 2                         NaN                 NaN                         NaN
# 3                         NaN                 NaN                         NaN
# 4                         NaN                 NaN                         NaN
#
#   intervention5_ingredient  intervention5_daily_dosage intervention5_units  \
# 0                      NaN                         NaN                 NaN
# 1                      NaN                         NaN                 NaN
# 2                      NaN                         NaN                 NaN
# 3                      NaN                         NaN                 NaN
# 4                      NaN                         NaN                 NaN
#
#   intervention5_original_text outcome10_name outcome10_domain outcome10_type  \
# 0                         NaN            NaN              NaN            NaN
# 1                         NaN            NaN              NaN            NaN
# 2                         NaN            NaN              NaN            NaN
# 3                         NaN            NaN              NaN            NaN
# 4                         NaN            NaN              NaN            NaN
#
#   outcome10_result outcome11_name outcome11_domain outcome11_type  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#   outcome11_result outcome12_name outcome12_domain outcome12_type  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#   outcome12_result outcome13_name outcome13_domain outcome13_type  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#   outcome13_result outcome14_name outcome14_domain outcome14_type  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#   outcome14_result outcome15_name outcome15_domain outcome15_type  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#   outcome15_result outcome16_name outcome16_domain outcome16_type  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#   outcome16_result outcome17_name outcome17_domain outcome17_type  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#   outcome17_result outcome18_name outcome18_domain outcome18_type  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#   outcome18_result intervention6_ingredient  intervention6_daily_dosage  \
# 0              NaN                      NaN                         NaN
# 1              NaN                      NaN                         NaN
# 2              NaN                      NaN                         NaN
# 3              NaN                      NaN                         NaN
# 4              NaN                      NaN                         NaN
#
#   intervention6_units intervention6_original_text
# 0                 NaN                         NaN
# 1                 NaN                         NaN
# 2                 NaN                         NaN
# 3                 NaN                         NaN
# 4                 NaN                         NaN
