# %% [markdown]
# # Defining Types of Articles

# %%
systematic_meta_analysis = [
    "Meta-Analysis",
    "Network Meta-Analysis",
    "Systematic Review"
    ]

# %%
clinical_trial = [
    "Adaptive Clinical Trial",
    "Clinical Study",
    "Clinical Trial",
    "Clinical Trial Protocol",
    "Clinical Trial, Phase I",
    "Clinical Trial, Phase II",
    "Clinical Trial, Phase III",
    "Clinical Trial, Phase IV",
    "Clinical Trial, Veterinary",
    "Controlled Clinical Trial",
    "Equivalence Trial",
    "Multicenter Study",
    "Pragmatic Clinical Trial",
    "Randomized Controlled Trial",
    "Randomized Controlled Trial, Veterinary"
]

# %%
observational_studies = [
    "Case Reports",
    "Comparative Study",
    "Evaluation Study",
    "Observational Study",
    "Observational Study, Veterinary",
    "Twin Study",
    "Validation Study",
    "Review",
    "Scientific Integrity Review",
    "Scoping Review"
]

# %%
# Initialize an empty list
all_study_types = []

# Extend the list with other lists
all_study_types.extend(systematic_meta_analysis)
all_study_types.extend(clinical_trial)
all_study_types.extend(observational_studies)

allowed_study_types = all_study_types

# Print the combined list
print("Total Study types:",len(all_study_types))
# Out:
# Total Study types: 28

# %% [markdown]
# # Loading Data

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv('Output/pubmed_hits_raw.csv')  
df.rename(columns={'Search Term': 'Synonyms'}, inplace=True)

# View first 5 rows
df.head()
# Out:
#    Root Name                                           Synonyms      PMID  \
# 0  Patchouli  Patchouli; patchouli oil; Pogostemon oil; patc...  40219102
# 1  Patchouli  Patchouli; patchouli oil; Pogostemon oil; patc...  39511253
# 2  Patchouli  Patchouli; patchouli oil; Pogostemon oil; patc...  38708994
# 3  Patchouli  Patchouli; patchouli oil; Pogostemon oil; patc...  38623714
# 4  Patchouli  Patchouli; patchouli oil; Pogostemon oil; patc...  38504994
#
#                                                Title  \
# 0  Unlocking the Therapeutic Potential of Patchou...
# 1  Comparative toxicity of three variant oils and...
# 2  Unveiling the phyto-restorative potential of e...
# 3  Unlocking liver health: Can tackling myosteato...
# 4  The critical role of toll-like receptor 4 in b...
#
#                                         Article Type  Publication Year  \
# 0                            Journal Article; Review              2025
# 1                 Journal Article; Comparative Study              2024
# 2                            Journal Article; Review              2024
# 3                            Journal Article; Review              2024
# 4  Journal Article; Review; Research Support, Non...              2024
#
#                                   PubMed URL
# 0  https://pubmed.ncbi.nlm.nih.gov/40219102/
# 1  https://pubmed.ncbi.nlm.nih.gov/39511253/
# 2  https://pubmed.ncbi.nlm.nih.gov/38708994/
# 3  https://pubmed.ncbi.nlm.nih.gov/38623714/
# 4  https://pubmed.ncbi.nlm.nih.gov/38504994/

# %%
df.shape
# Out:
# (3942, 7)

# %%
df.groupby(['Root Name'])['Root Name'].count().sort_values().head(25)
# Out:
# Root Name
# Ylang Ylang        46
# Patchouli          63
# Bois de Landes     75
# Sandalwood         81
# Jasmine           110
# Bergamot          145
# Orange-Neroli     576
# Orange/Neroli     585
# Saffron           707
# Lavender          742
# Linalool          812
# Name: Root Name, dtype: int64

# %% [markdown]
# # Adding Synonyms

# %%
# import numpy as np

# synonyms_df = pd.read_excel("Data/76 Ingredient List.xlsx")
# synonyms_df['Common Name(s)'] = synonyms_df['Common Name(s)'].astype(str).str.replace(',', ';')
# synonyms_df['Other Search Words'] = synonyms_df['Other Search Words'].astype(str).str.replace(',', ';')
# synonyms_df = synonyms_df.replace(['nan', np.nan], '') 
# synonyms_df['Synonyms'] = (
#     synonyms_df['Common Name(s)'].fillna('')
#     .str.strip() + '; ' +
#     synonyms_df['Scientific Name(s)'].fillna('')
#     .str.strip() + '; ' +
#     synonyms_df['Other Search Words'].fillna('')
#     .str.strip()
# )
# synonyms_df.head()

# %%
# df_merged = df.merge(
#     synonyms_df[['Ingredient', 'Synonyms']],  # only the columns we need
#     left_on='Root Name',               # key in df
#     right_on='Ingredient',             # key in synonyms_df
#     how='left'                         # keep all rows from df
# )

# # Drop duplicate 'Ingredient' column
# df = df_merged.drop(columns=['Ingredient'])
# df.head()

# %% [markdown]
# # Defining Neuraci Type

# %%
# Define mapping of NeuraciTypes
priority_mapping = [
    (systematic_meta_analysis,'Systematic Review & Meta Analysis'), # 1st Priority
    (clinical_trial, 'Clinical Trials'),                            # 2nd Priority
    (observational_studies, 'Observational Studies & Reviews'),     # 3rd Priority

]

# Function to assign NeuraciType based on priority
def classify_type(type_list):
    for reference_list, category in priority_mapping:
        if any(item in reference_list for item in type_list):
            return category
    return 'Unclassified'  # optional, in case nothing matches

# Create new column with a list of article types
df['Type_list'] = df['Article Type'].apply(lambda x: set([item.strip() for item in x.split(';')]))


# Apply function to create new column
df['PubMedType'] = df['Type_list'].apply(
    lambda x: ', '.join(x.intersection(set(allowed_study_types))) if isinstance(x, set) else ''
)
df["NeuraciType"] = df['Type_list'].apply(lambda x: pd.Series(classify_type(x)))

df.head()
# Out:
#    Root Name                                           Synonyms      PMID  \
# 0  Patchouli  Patchouli; patchouli oil; Pogostemon oil; patc...  40219102
# 1  Patchouli  Patchouli; patchouli oil; Pogostemon oil; patc...  39511253
# 2  Patchouli  Patchouli; patchouli oil; Pogostemon oil; patc...  38708994
# 3  Patchouli  Patchouli; patchouli oil; Pogostemon oil; patc...  38623714
# 4  Patchouli  Patchouli; patchouli oil; Pogostemon oil; patc...  38504994
#
#                                                Title  \
# 0  Unlocking the Therapeutic Potential of Patchou...
# 1  Comparative toxicity of three variant oils and...
# 2  Unveiling the phyto-restorative potential of e...
# 3  Unlocking liver health: Can tackling myosteato...
# 4  The critical role of toll-like receptor 4 in b...
#
#                                         Article Type  Publication Year  \
# 0                            Journal Article; Review              2025
# 1                 Journal Article; Comparative Study              2024
# 2                            Journal Article; Review              2024
# 3                            Journal Article; Review              2024
# 4  Journal Article; Review; Research Support, Non...              2024
#
#                                   PubMed URL  \
# 0  https://pubmed.ncbi.nlm.nih.gov/40219102/
# 1  https://pubmed.ncbi.nlm.nih.gov/39511253/
# 2  https://pubmed.ncbi.nlm.nih.gov/38708994/
# 3  https://pubmed.ncbi.nlm.nih.gov/38623714/
# 4  https://pubmed.ncbi.nlm.nih.gov/38504994/
#
#                                            Type_list         PubMedType  \
# 0                          {Journal Article, Review}             Review
# 1               {Journal Article, Comparative Study}  Comparative Study
# 2                          {Journal Article, Review}             Review
# 3                          {Journal Article, Review}             Review
# 4  {Journal Article, Research Support, Non-U.S. G...             Review
#
#                        NeuraciType
# 0  Observational Studies & Reviews
# 1  Observational Studies & Reviews
# 2  Observational Studies & Reviews
# 3  Observational Studies & Reviews
# 4  Observational Studies & Reviews

# %%
ingredients = ["Patchouli","Sandalwood","Ylang Ylang"]

# %%
# no_abstract_pmids = [
#     16942582,
#     18349580,
#     18781101,
#     19901509,
#     27333653,
#     27788889,
#     9536426
# ]

# none_pmids = [
#     23652808,
#     25163405,
#     25704097,
#     26165898,
#     28117719,
#     28460831,
#     28895508,
#     29543548,
#     30541521,
#     31618733,
#     32037737,
#     32407947,
#     32439404,
#     35917731
# ]

# %%
from meta_data_generation import process_pmids

#ingredient_df = df[df['Root Name'].isin([39069654])]
ingredient_df = df[df['Root Name'].isin(ingredients)]
#ingredient_df = df[(df['Root Name'].isin(ingredients)) & (df['NeuraciType'] == 'Clinical Trials')]
#ingredient_df = df[(df['Root Name'].isin(ingredients)) & (df['PMID'].isin([10205628, 138507, 15244513, 15453700,39069654]))]
process_pmids(ingredient_df['Root Name'],ingredient_df['Synonyms'],ingredient_df['PMID'], ingredient_df['PubMedType'],output_file="output/test_10|31.json")
# Out:
# Processing PMIDs:  56%|█████▋    | 107/190 [00:00<00:00, 158.10pmid/s]
# No abstract: 8789238
# No abstract: 3443530
# No abstract: 28150651
# Processing PMIDs:  65%|██████▍   | 123/190 [00:03<00:02, 25.58pmid/s]
# No abstract: 6028683
# Processing PMIDs:  83%|████████▎ | 157/190 [00:04<00:01, 30.16pmid/s]
# No abstract: 11011949
# Processing PMIDs:  86%|████████▌ | 163/190 [00:05<00:01, 20.96pmid/s]
# No abstract: 8565465
# Processing PMIDs: 100%|██████████| 190/190 [00:06<00:00, 28.16pmid/s]
# No abstract: 4416336
# [{'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 40219102,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['anti-oxidant',
#     'anti-inflammatory',
#     'antimicrobial',
#     'antidepressant',
#     'anticancer'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ['colds',
#     'fevers',
#     'headaches',
#     'inflammation',
#     'digestive disorders',
#     'insect bites',
#     'snake bites'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to provide a comprehensive overview of the existing literature on the phytochemical composition, pharmacological properties, and underlying mechanisms of action of patchouli essential oil and plant extracts obtained from patchouli leaves.',
#    'conclusion': 'this review underscores the need for further research to validate and develop the medicinal applications of patchouli leaves, providing a foundation for future healthcare advancements.',
#    'outcomes': [{'name': 'colds',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'fevers',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'headaches',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'inflammation',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'digestive disorders',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'insect bites',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'snake bites',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['medicinal plant',
#     'patchouli (pogostemon cablin)',
#     'patchouli leaves',
#     'pharmacological activities',
#     'phytochemistry'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 39511253,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['animals', 'cell lines'],
#    'experimental_model': ['in vitro'],
#    'population': 'rhipicephalus sanguineus sensu lato unfed adults and normal fibroblast cells (bj-1)',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['acaricidal activity'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['cytotoxicity'],
#    'interventions': [{'ingredient': 'patchouli oil',
#      'daily_dosage': 0.62,
#      'units': '%',
#      'original_text': 'up to a concentration of 0.62% (cytotoxicity%= 34.4%)'}],
#    'usage': ['not mentioned'],
#    'conditions': ['tick infestation'],
#    'biomarkers': ['cytotoxicity'],
#    'functions': [],
#    'purpose': 'to evaluate the acaricidal activity and cytotoxicity of myrrh, patchouli, and cypress oils and their nanoemulsions against rhipicephalus sanguineus and normal fibroblast cells.',
#    'conclusion': 'the three oils and their nanoemulsions have good acaricidal activity against rhipicephalus sanguineus unfed adults, but further toxicity studies on mammals are needed to ensure safe use.',
#    'outcomes': [{'name': 'tick infestation',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'cytotoxicity',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'mixed'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['rhipicephalus sanguineus',
#     'acaricide',
#     'dogs',
#     'fibroblast cell',
#     'nanoemulsion',
#     'tem'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 38708994,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'individuals with atopic dermatitis',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['anti-inflammatory effect',
#     'anti-eczematic effect',
#     'antipruritic effect'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ['atopic dermatitis'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to explore the phyto-restorative potential of essential oils, including patchouli oil, for treating atopic dermatitis by providing a natural therapy to circumvent noxious symptoms.',
#    'conclusion': 'essential oils like patchouli oil exhibit anti-inflammatory, anti-eczematic, and antipruritic properties, providing a natural treatment option for atopic dermatitis by impeding inflammatory mediators and immunological hyperactivities.',
#    'outcomes': [{'name': 'atopic dermatitis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': ['atopic dermatitis'],
#    'symptoms': ['erythema', 'inflamed lesions'],
#    'keywords': ['anti-inflammatory',
#     'antioxidant',
#     'atopic dermatitis',
#     'essential oils',
#     'ethereal distillates'],
#    'location': 'not mentioned',
#    'mechanism': ['impeding inflammatory mediators',
#     'reducing immunological hyperactivities']}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 38623714,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['humans', 'animals'],
#    'experimental_model': ['in vivo', 'in vitro'],
#    'population': 'individuals with metabolic dysfunction-associated steatotic liver disease (masld)',
#    'study_type': ['review'],
#    'focus': ['secondary'],
#    'benefits': ['improve liver and muscle phenotypes'],
#    'synergies_interactions_positive': ['combination of diet and physical activity acts synergistically in liver, muscle and white adipose tissue'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'patchouli alcohol',
#      'daily_dosage': 0,
#      'units': '',
#      'original_text': 'patchouli alcohol'}],
#    'usage': ['not mentioned'],
#    'conditions': ['metabolic dysfunction-associated steatotic liver disease'],
#    'biomarkers': ['muscle fat',
#     'liver fat',
#     'fatty acid oxidation',
#     'inflammation',
#     'insulin sensitivity'],
#    'functions': ['not mentioned'],
#    'purpose': 'to identify interventions reducing myosteatosis and their impact on liver function in masld',
#    'conclusion': 'several pharmacological interventions, including patchouli alcohol, improve liver and muscle phenotypes in pre-clinical studies by increasing fatty acid oxidation and anti-inflammatory properties, suggesting new therapeutic strategies for masld.',
#    'outcomes': [{'name': 'metabolic dysfunction-associated steatotic liver disease',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'muscle fat',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'liver fat',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'fatty acid oxidation',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'inflammation',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'insulin sensitivity',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'}],
#    'diseases': ['metabolic dysfunction-associated steatotic liver disease'],
#    'symptoms': [],
#    'keywords': ['masld',
#     'diet',
#     'liver',
#     'myosteatosis',
#     'physical activity',
#     'skeletal muscle'],
#    'location': 'not mentioned',
#    'mechanism': ['increasing fatty acid oxidation',
#     'anti-inflammatory properties']}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 38504994,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['humans', 'animals', 'cell lines'],
#    'experimental_model': ['in vivo', 'in vitro'],
#    'population': 'individuals with osteoporosis',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['improve bone metabolism'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'patchouli alcohol',
#      'daily_dosage': 0,
#      'units': '',
#      'original_text': 'patchouli alcohol'}],
#    'usage': ['not mentioned'],
#    'conditions': ['osteoporosis'],
#    'biomarkers': ['tlr4 expression'],
#    'functions': ['bone metabolism'],
#    'purpose': 'to summarize the findings on the role of tlr4 in osteoporosis and its potential as a therapeutic target.',
#    'conclusion': 'patchouli alcohol and other agents have been shown to improve bone metabolism by inhibiting tlr4 expression, highlighting the potential of targeting tlr4 for osteoporosis treatment.',
#    'outcomes': [{'name': 'osteoporosis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'tlr4 expression',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'bone metabolism',
#      'domain': 'function',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': ['osteoporosis'],
#    'symptoms': [],
#    'keywords': ['tlr4',
#     'mechanism',
#     'osteoblast',
#     'osteoclasts',
#     'osteoporosis',
#     'treatment'],
#    'location': 'not mentioned',
#    'mechanism': ['inhibition of tlr4 expression']}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 38358844,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to discuss the impact of transitioning to a renewable and biodegradable future in fragrance chemistry.',
#    'conclusion': 'patchouli has become the new moss in the chypre genre, but there is an increasing demand for more musks.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['crude sulfate terpentine',
#     'fragrances',
#     'green chemistry',
#     'odorants',
#     'olfactory properties',
#     'renewability',
#     'sustainability',
#     'terpenoids'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 37920320,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'patients with covid-19',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['antiviral activity', 'anti-inflammatory effects'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ['covid-19'],
#    'biomarkers': ['cytokine storm'],
#    'functions': [],
#    'purpose': 'to review the literature to introduce some effective plant-derived antioxidants to prevent and treat covid-19.',
#    'conclusion': 'natural products, including patchouli alcohol, may play a critical role against sars-covid-2 via direct antiviral activity and indirect antioxidant and anti-inflammatory mechanisms.',
#    'outcomes': [{'name': 'covid-19',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not reported'},
#     {'name': 'cytokine storm',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not reported'}],
#    'diseases': ['covid-19'],
#    'symptoms': [],
#    'keywords': ['angiotensin-converting enzyme2',
#     'antiviral',
#     'coronavirus disease 2019',
#     'herbal antioxidants',
#     'inflammation'],
#    'location': 'not mentioned',
#    'mechanism': ['inhibition of viral entry',
#     'suppuration of virus function',
#     'anti-inflammatory']}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 37110702,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['anti-inflammatory',
#     'antioxidant',
#     'anti-mutagenic',
#     'antimicrobial',
#     'antidepressant',
#     'anticancer',
#     'antiemetic',
#     'antiviral',
#     'cytotoxic'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['ingestion', 'inhalation'],
#    'conditions': ['colds',
#     'fever',
#     'vomiting',
#     'headaches',
#     'stomachaches',
#     'depression',
#     'stress'],
#    'biomarkers': [],
#    'functions': ['appetite regulation', 'sexual attraction enhancement'],
#    'purpose': 'to close the knowledge gap regarding the pharmacological effects of patchouli essential oil and pachypodol.',
#    'conclusion': 'pachypodol, a key bioactive molecule found in pogostemon cablin, has a variety of biological activities including anti-inflammatory, antioxidant, anti-mutagenic, antimicrobial, antidepressant, anticancer, antiemetic, antiviral, and cytotoxic effects.',
#    'outcomes': [{'name': 'colds',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'fever',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'vomiting',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'headaches',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'stomachaches',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'depression',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'stress',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'appetite regulation',
#      'domain': 'function',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'sexual attraction enhancement',
#      'domain': 'function',
#      'type': 'secondary',
#      'result': 'not reported'}],
#    'diseases': ['colds',
#     'fever',
#     'vomiting',
#     'headaches',
#     'stomachaches',
#     'depression',
#     'stress'],
#    'symptoms': [],
#    'keywords': ['pogostemon cablin',
#     'anti-cancerous',
#     'anti-inflammatory',
#     'anti-microbial',
#     'essential oil',
#     'flavonoids',
#     'pachypodol'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 36878051,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': "individuals with alzheimer's disease",
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ["alzheimer's disease"],
#    'biomarkers': ['sirt1'],
#    'functions': ['cognition', 'memory'],
#    'purpose': "to summarize the correlation between sirt1 and alzheimer's disease and to identify studies investigating the anti-alzheimer's disease properties of natural molecules as modulators of sirt1 and sirt1-mediated signaling pathways.",
#    'conclusion': "natural molecules, including patchouli, have the potential to modulate sirt1 and sirt1 signaling pathways, providing a potentially novel multi-mechanistic therapeutic strategy for alzheimer's disease.",
#    'outcomes': [{'name': "alzheimer's disease",
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not reported'},
#     {'name': 'sirt1',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'cognition',
#      'domain': 'function',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'memory',
#      'domain': 'function',
#      'type': 'secondary',
#      'result': 'not reported'}],
#    'diseases': ["alzheimer's disease"],
#    'symptoms': [],
#    'keywords': ["alzheimer's disease",
#     'natural molecules',
#     'pharmacological mechanism',
#     'phytochemicals',
#     'sirt1'],
#    'location': 'not mentioned',
#    'mechanism': ['sirt1 modulation']}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 36511100,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': "to review the patent literature on pogostemon cablin's therapeutic effects.",
#    'conclusion': 'this current pogostemon cablin literature analysis study will facilitate bridging the gap between further exploring the potential of this plant through novel investigations.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['herba pogostemonis',
#     'patchouli',
#     'pogostemon cablin',
#     'pogostemon patchouli',
#     'antibacterial',
#     'antitumor',
#     'antiviral'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 36212991,
#   'pubmed_type': 'Case Reports',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['microorganisms'],
#    'experimental_model': ['in vitro'],
#    'population': 'immature and adult stages of ctenocephalides felis',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['insecticidal activity'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'pogostemon cablin essential oil',
#      'daily_dosage': 200,
#      'units': 'ug.cm-2',
#      'original_text': '200 μg.cm-2'}],
#    'usage': ['not mentioned'],
#    'conditions': ['not mentioned'],
#    'biomarkers': ['not mentioned'],
#    'functions': ['not mentioned'],
#    'purpose': 'to evaluate the in vitro insecticidal activity of the essential oil of pogostemon cablin against immature and adult stages of ctenocephalides felis',
#    'conclusion': 'the essential oil of pogostemon cablin contained patchoulol, alpha-bulnesene, and alpha-guayene as major constituents and had insecticidal activity against the immature and adult stages of ctenocephalides felis.',
#    'outcomes': [{'name': 'insecticidal activity',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['flea', 'patchouli', 'sesquiterpene alcohol', 'volatile oil'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 35862879,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'patients experiencing chemotherapy-induced mucositis',
#    'study_type': ['review'],
#    'focus': ['secondary'],
#    'benefits': ['mitigating chemotherapy-induced mucositis'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ['chemotherapy-induced mucositis'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to evaluate recent literature on nonpharmacological strategies to improve chemotherapy-induced mucositis',
#    'conclusion': 'alternatives to pharmacological approaches, including natural products like patchouli, show great potential for preventing and treating chemotherapy-induced mucositis and should be further developed for clinical use.',
#    'outcomes': [{'name': 'chemotherapy-induced mucositis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': ['mucositis'],
#    'symptoms': [],
#    'keywords': [],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 35588098,
#   'pubmed_type': 'Randomized Controlled Trial, Veterinary',
#   'metadata': {'duration_days': 30,
#    'sample_size': 5,
#    'sample_gender': ['male'],
#    'species': ['animals', 'cell lines'],
#    'experimental_model': ['in vivo', 'in vitro'],
#    'population': 'c57bl/6 male mice',
#    'study_type': ['randomized controlled trial'],
#    'focus': ['primary'],
#    'benefits': ['protective effects on myocardial ischaemia-reperfusion injury'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'patchouli alcohol',
#      'daily_dosage': 40,
#      'units': 'mg/kg',
#      'original_text': '10, 20, 40 mg/kg'},
#     {'ingredient': 'patchouli alcohol',
#      'daily_dosage': 100,
#      'units': 'umol/l',
#      'original_text': '1, 10 or 100 umol/l'}],
#    'usage': ['injection'],
#    'conditions': ['myocardial ischaemia-reperfusion injury'],
#    'biomarkers': ['notch1',
#     'hes1',
#     'atf4',
#     'p-perk/perk',
#     'cleaved caspase-3/caspase-3',
#     'ck-mb',
#     'ctni',
#     'ctnt'],
#    'functions': ['cardiac function'],
#    'purpose': 'to examine the therapeutic effect of pa on myocardial ischaemia-reperfusion (i/r) injury.',
#    'conclusion': 'pa protects against mi/r, possibly by modulating er stress, apoptosis and the notch1/hes1 signalling pathways.',
#    'outcomes': [{'name': 'myocardial ischaemia-reperfusion injury',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'notch1',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'hes1',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'atf4',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'p-perk/perk',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'cleaved caspase-3/caspase-3',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'ck-mb',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'ctni',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'ctnt',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'cardiac function',
#      'domain': 'function',
#      'type': 'secondary',
#      'result': 'improved'}],
#    'diseases': ['ischaemic heart diseases'],
#    'symptoms': [],
#    'keywords': ['endoplasmic reticulum stress',
#     'apoptosis',
#     'cardiac function'],
#    'location': 'not mentioned',
#    'mechanism': ['modulating er stress',
#     'apoptosis',
#     'notch1/hes1 signalling pathways']}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 35282804,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['regulating the gastrointestinal tract',
#     'inhibition of pathogenic microorganisms',
#     'anti-inflammation'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ['vomiting',
#     'chest tension',
#     'tiredness',
#     'abdominal pain',
#     'diarrhea',
#     'headache'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to provide a comprehensive review of the traditional uses, phytochemistry, pharmacology, quality control, industrial application, pharmacokinetics, and network pharmacology of pogostemon cablin.',
#    'conclusion': 'pogostemon cablin possesses multi-pharmacological activities, including regulating the gastrointestinal tract, inhibition of pathogenic microorganisms, and anti-inflammation, providing scientific interpretation for its clinical usage.',
#    'outcomes': [{'name': 'vomiting',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'chest tension',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'tiredness',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'abdominal pain',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'diarrhea',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'headache',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'}],
#    'diseases': [],
#    'symptoms': ['vomiting',
#     'chest tension',
#     'tiredness',
#     'abdominal pain',
#     'diarrhea',
#     'headache'],
#    'keywords': ['history of uses',
#     'industrical applications',
#     'patchouli alcohol',
#     'pharmacokinetics',
#     'pharmacology',
#     'phytochemistry',
#     'pogostemon cablin',
#     'pogostemonis herba',
#     'pogostone',
#     'review'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 34951207,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['anti-tumor',
#     'anti-inflammatory',
#     'antibacterial',
#     'antioxidant'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ['not mentioned'],
#    'biomarkers': ['not mentioned'],
#    'functions': ['not mentioned'],
#    'purpose': 'to review the biosynthesis and metabolism regulation of terpenoids in pogostemon cablin to provide a reference for the development, protection, and utilization of p. cablin resources.',
#    'conclusion': 'the study reviews key enzyme genes in biosynthesis, transcription factors in metabolism regulation, and spatio-temporal expression of terpene synthase in pogostemon cablin, highlighting their potential for obtaining high-content terpenoids.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['pogostemon cablin',
#     'biosynthesis',
#     'metabolism regulation',
#     'patchouli alcohol',
#     'pogostone'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 33413544,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['anti-peptic ulcer effect',
#     'antimicrobial effect',
#     'anti-oxidative effect',
#     'anti-inflammatory effect',
#     'effect on ischemia/reperfusion injury',
#     'analgesic effect',
#     'antitumor effect',
#     'antidiabetic effect',
#     'anti-hypertensive effect',
#     'immunoregulatory effect'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ['colds', 'nausea', 'fever', 'headache', 'diarrhea'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to summarize the recent progress in phytochemistry, pharmacology, and mechanisms of action of pogostemon cablin benth and provide a reference for future studies focused on clinical applications.',
#    'conclusion': 'patchouli, scientifically known as pogostemon cablin benth, has various pharmacological impacts including anti-peptic ulcer, antimicrobial, anti-oxidative, anti-inflammatory, analgesic, antitumor, antidiabetic, anti-hypertensive, and immunoregulatory effects.',
#    'outcomes': [{'name': 'colds',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'nausea',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'fever',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'headache',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'diarrhea',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'}],
#    'diseases': [],
#    'symptoms': ['colds', 'nausea', 'fever', 'headache', 'diarrhea'],
#    'keywords': ['biological activities',
#     'mechanisms',
#     'patchouli alcohol',
#     'pogostemon cablin benth'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 33316383,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'individuals with depressive disorder',
#    'study_type': ['not mentioned'],
#    'focus': ['not mentioned'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ['depression'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to summarize the classification of depression and the use of natural volatile oils as potential anti-depressant treatments.',
#    'conclusion': 'the review highlights the potential of natural volatile oils from herbal medicines as alternative treatments for depressive disorders, emphasizing their good antidepressant effects with little toxicity and side effects.',
#    'outcomes': [{'name': 'depression',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not reported'}],
#    'diseases': ['depressive disorder'],
#    'symptoms': [],
#    'keywords': ['depression',
#     'volatile oils',
#     'natural medicine',
#     'antidepressant',
#     'blood-brain barrier',
#     'clinical use',
#     'administration routes'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 33049685,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'patients with coronary disease and other related diseases',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['cardioprotective effects'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ['cardiovascular diseases',
#     'hypertension',
#     'angina pectoris',
#     'hyperlipidemia',
#     'thromboembolism',
#     'coronary heart disease',
#     'heart failure',
#     'venous insufficiency',
#     'arrhythmia',
#     'diabetes',
#     'cancer'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to discuss the cardioprotective effects of lamiaceae and their active secondary metabolites, as well as mechanism of action against cardiovascular diseases.',
#    'conclusion': 'studies on developing new, effective and safe natural products from lamiaceae are promising and may offer prevention and treatment for patients with coronary disease and other related diseases.',
#    'outcomes': [{'name': 'cardiovascular diseases',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not reported'},
#     {'name': 'hypertension',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'angina pectoris',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'hyperlipidemia',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'thromboembolism',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'coronary heart disease',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'heart failure',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'venous insufficiency',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'arrhythmia',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'diabetes',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'},
#     {'name': 'cancer',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not reported'}],
#    'diseases': ['coronary heart disease'],
#    'symptoms': [],
#    'keywords': [],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 33039955,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['anti-influenza virus',
#     'anti-depressant',
#     'anti-nociceptive',
#     'vasorelaxation',
#     'lung protection',
#     'brain protection',
#     'anti-ulcerogenic',
#     'anti-colitis',
#     'pre-biotic-like',
#     'anti-inflammatory',
#     'anti-cancer',
#     'protective activities against metabolic diseases'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': ['influenza',
#     'depression',
#     'nociception',
#     'lung diseases',
#     'brain diseases',
#     'ulcers',
#     'colitis',
#     'metabolic diseases',
#     'cancer',
#     'inflammation'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to explore the possibility of developing patchouli alcohol as a functional food material or promising drug for the prevention and treatment of human diseases.',
#    'conclusion': 'patchouli alcohol mediates health benefits through multiple molecular targets and working mechanisms.',
#    'outcomes': [{'name': 'influenza',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'depression',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'nociception',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'lung diseases',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'brain diseases',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'ulcers',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'colitis',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'metabolic diseases',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'cancer',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'inflammation',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'}],
#    'diseases': ['influenza',
#     'depression',
#     'lung diseases',
#     'brain diseases',
#     'ulcers',
#     'colitis',
#     'metabolic diseases',
#     'cancer'],
#    'symptoms': ['nociception', 'inflammation'],
#    'keywords': ['biological mechanisms',
#     'health benefits',
#     'patchouli alcohol'],
#    'location': 'not mentioned',
#    'mechanism': ['multiple molecular targets', 'working mechanisms']}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 32907352,
#   'pubmed_type': 'Randomized Controlled Trial',
#   'metadata': {'duration_days': 2,
#    'sample_size': 50,
#    'sample_gender': ['not mentioned'],
#    'species': ['humans'],
#    'experimental_model': ['in vivo'],
#    'population': 'emergency nurses',
#    'study_type': ['randomized controlled trial'],
#    'focus': ['primary'],
#    'benefits': ['stress reduction', 'increased compassion satisfaction'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'patchouli oil',
#      'daily_dosage': 0.1,
#      'units': 'ml',
#      'original_text': '5% patchouli oil in sweet almond oil'}],
#    'usage': ['inhalation'],
#    'conditions': ['stress',
#     'compassion satisfaction',
#     'compassion fatigue',
#     'burnout'],
#    'biomarkers': ['blood pressure', 'heart rate'],
#    'functions': ['stress',
#     'compassion satisfaction',
#     'compassion fatigue',
#     'burnout'],
#    'purpose': 'to investigate the effects of patchouli inhalation by emergency nurses on their stress, compassion satisfaction, compassion fatigue, burnout, blood pressure, and heart rate.',
#    'conclusion': 'inhalation of patchouli oil effectively reduced the levels of stress and increased compassion satisfaction in emergency nurses, suggesting that patchouli oil inhalation may improve the professional quality of life of emergency nurses.',
#    'outcomes': [{'name': 'stress',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'compassion satisfaction',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'compassion fatigue',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'burnout',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'no effect'},
#     {'name': 'blood pressure',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'no effect'},
#     {'name': 'heart rate',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'no effect'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['compassion satisfaction',
#     'emergency nurses',
#     'patchouli',
#     'stress'],
#    'location': 'south korea',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 31643144,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to develop an efficient biotransformation and to characterize the biocatalytic mechanism of the pts in detail.',
#    'conclusion': 'the pts showed an unusual substrate inhibition for sesquiterpene synthases indicating an intermediate sesquiterpene formed in the active center.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['biocatalysis',
#     'biocatalytic mechanism',
#     'patchouli oil',
#     'patchoulol synthase',
#     'sesquiterpenes'],
#    'location': 'not mentioned',
#    'mechanism': ['proton transfer',
#     'substrate inhibition',
#     'protonation',
#     'deprotonation']}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 29751722,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'patients with diarrhea and damp-heat',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'patchouli',
#      'daily_dosage': 0,
#      'units': '',
#      'original_text': ''}],
#    'usage': ['not mentioned'],
#    'conditions': ['diarrhea', 'damp-heat'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to compare the treatment approaches of ye tianshi and xue shengbai for diarrhea with damp-heat using traditional chinese medicine.',
#    'conclusion': 'the study summarizes the similarities and differences in the medication approaches of ye tianshi and xue shengbai for treating dampness and heat, providing a reference for clinical treatment.',
#    'outcomes': [{'name': 'diarrhea',
#      'domain': 'condition',
#      'type': 'not reported',
#      'result': 'not reported'}],
#    'diseases': ['diarrhea'],
#    'symptoms': [],
#    'keywords': ['xue shengbai',
#     'ye tianshi',
#     'diarrhea',
#     'dysentery',
#     'pharmacy'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Patchouli',
#   'synonyms': 'Patchouli; patchouli oil; Pogostemon oil; patchouli leaf; Pogostemon cablin, Pogostemon heyneanus, Patchouli terpenes, Pogostemon patchouli',
#   'PMID': 29600757,
#   'pubmed_type': 'Review',
# ...
#    'mechanism': []}},
#  {'root_name': 'Sandalwood',
#   'synonyms': 'Sandalwood; sandalwood oil; Indian sandalwood; Australian sandalwood; Sandalwood resinoid; Santalum album; Santalum spicatum; Santalum austrocaledonicum',
#   'PMID': 33480340,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to discuss the various extraction and characterization techniques used to isolate the essential bioactive compounds from three plant species and the biotic and abiotic factors that affect the quantity and quality of the plants secondary metabolites.',
#    'conclusion': 'the review summarizes different types of extraction and characterization techniques utilized commercially by the food, drug, and pharmaceutical industries for better output and environmentally- and health-benefiting products with special reference to three industrially important plants: leonotis leonurus, santalum album, and aloe vera.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['aloe vera',
#     'leonotis leonurus',
#     'santalum album',
#     'bioactive compounds',
#     'extraction process',
#     'neutraceuticals'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Sandalwood',
#   'synonyms': 'Sandalwood; sandalwood oil; Indian sandalwood; Australian sandalwood; Sandalwood resinoid; Santalum album; Santalum spicatum; Santalum austrocaledonicum',
#   'PMID': 33155997,
#   'pubmed_type': 'Systematic Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'individuals at risk or affected by covid-19',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['antioxidant',
#     'immunomodulatory',
#     'cardiotonic',
#     'general tonic'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'santalum album',
#      'daily_dosage': 0,
#      'units': '',
#      'original_text': 'not mentioned'}],
#    'usage': ['inhalation'],
#    'conditions': ['covid-19'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to explore the role of unani pharmacology in the prevention and management of covid-19.',
#    'conclusion': 'the study suggests that unani formulations, including aromatic herbs like santalum album, may have potential roles in the prevention and management of covid-19 through antioxidant, immunomodulatory, cardiotonic, and general tonic actions.',
#    'outcomes': [{'name': 'covid-19',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not reported'}],
#    'diseases': ['covid-19'],
#    'symptoms': [],
#    'keywords': ['covid-19',
#     'joshandah',
#     'unani pharmacology',
#     'epidemic disease',
#     'herbal decoction'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Sandalwood',
#   'synonyms': 'Sandalwood; sandalwood oil; Indian sandalwood; Australian sandalwood; Sandalwood resinoid; Santalum album; Santalum spicatum; Santalum austrocaledonicum',
#   'PMID': 32401415,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'patients with cutaneous leishmaniasis',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'santalum album',
#      'daily_dosage': 0,
#      'units': '',
#      'original_text': 'santalum album l.'}],
#    'usage': ['topical'],
#    'conditions': ['cutaneous leishmaniasis'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to describe the herbal and traditional remedies in the treatment of cutaneous leishmaniasis with an overview on related available evidence in modern medicine.',
#    'conclusion': 'the sages of traditional persian medicine have recommended several systemic or topical medications, in addition to physical procedures, for treatment of cutaneous leishmaniasis, all of which could be a base for conducting further research on its efficacy.',
#    'outcomes': [{'name': 'cutaneous leishmaniasis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not reported'}],
#    'diseases': ['cutaneous leishmaniasis'],
#    'symptoms': [],
#    'keywords': ['cutaneous leishmaniasis',
#     'herbal medicine',
#     'traditional medicine'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Sandalwood',
#   'synonyms': 'Sandalwood; sandalwood oil; Indian sandalwood; Australian sandalwood; Sandalwood resinoid; Santalum album; Santalum spicatum; Santalum austrocaledonicum',
#   'PMID': 29257757,
#   'pubmed_type': 'Randomized Controlled Trial',
#   'metadata': {'duration_days': 21,
#    'sample_size': 'not mentioned',
#    'sample_gender': ['female'],
#    'species': ['humans'],
#    'experimental_model': ['in vivo'],
#    'population': 'women with abnormal vaginal discharge',
#    'study_type': ['randomized controlled trial', 'single-blind trial'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'sandal sufaid',
#      'daily_dosage': 20,
#      'units': 'g',
#      'original_text': '10 g of test drug b.d for 21 days'}],
#    'usage': ['ingestion'],
#    'conditions': ['abnormal vaginal discharge',
#     'bacterial vaginosis',
#     'candidiasis',
#     'trichomoniasis'],
#    'biomarkers': [],
#    'functions': ['pain'],
#    'purpose': 'to assess efficacy of sandal sufaid, maghze tukhme bakayin and khaste tamar hindi in syndromic management of sailanur rehm',
#    'conclusion': 'the formulation can effectively alleviate the disease with associated symptoms without any side effects. it can be used in syndromic management of vaginal discharge.',
#    'outcomes': [{'name': 'abnormal vaginal discharge',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'bacterial vaginosis',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'candidiasis',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'trichomoniasis',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'pain',
#      'domain': 'function',
#      'type': 'secondary',
#      'result': 'improved'}],
#    'diseases': ['bacterial vaginosis', 'candidiasis', 'trichomoniasis'],
#    'symptoms': [],
#    'keywords': ['bakayin',
#     'sailanur rehm',
#     'sandal sufaid',
#     'tamar hindi',
#     'syndrome'],
#    'location': 'india',
#    'mechanism': []}},
#  {'root_name': 'Sandalwood',
#   'synonyms': 'Sandalwood; sandalwood oil; Indian sandalwood; Australian sandalwood; Sandalwood resinoid; Santalum album; Santalum spicatum; Santalum austrocaledonicum',
#   'PMID': 26435892,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': ['cis-4-hydroxy-l-proline',
#     'trans-4-hydroxy-l-proline',
#     '3, 4 dehydroproline',
#     'pyrrolizidine-2-carboxylic acid',
#     'sym. homospermidine',
#     'γ-glutamyl-s-propenyl cysteine superoxide'],
#    'functions': [],
#    'purpose': 'to summarize the studies on the amino acids in sandal.',
#    'conclusion': 'sandal contains several unique amino acids and amines, including cis-4-hydroxy-l-proline and sym. homospermidine, which are not found in other plants.',
#    'outcomes': [{'name': 'cis-4-hydroxy-l-proline',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'not reported'},
#     {'name': 'trans-4-hydroxy-l-proline',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'not reported'},
#     {'name': '3, 4 dehydroproline',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'not reported'},
#     {'name': 'pyrrolizidine-2-carboxylic acid',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'not reported'},
#     {'name': 'sym. homospermidine',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'not reported'},
#     {'name': 'γ-glutamyl-s-propenyl cysteine superoxide',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'not reported'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['biosynthetic pathways',
#     'hydroxy prolines',
#     'lachrymatory precursor',
#     'sandal',
#     'sym. homospermidine'],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Sandalwood',
#   'synonyms': 'Sandalwood; sandalwood oil; Indian sandalwood; Australian sandalwood; Sandalwood resinoid; Santalum album; Santalum spicatum; Santalum austrocaledonicum',
#   'PMID': 16604360,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['not mentioned'],
#    'experimental_model': ['not mentioned'],
#    'population': 'not mentioned',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to explore the current state of chemical and biotechnological conversion and diversification of lipids as renewable resources.',
#    'conclusion': 'santalbic acid from santalum album is becoming industrially available for new and interesting functionalities.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': [],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Sandalwood',
#   'synonyms': 'Sandalwood; sandalwood oil; Indian sandalwood; Australian sandalwood; Sandalwood resinoid; Santalum album; Santalum spicatum; Santalum austrocaledonicum',
#   'PMID': 15910320,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 431,
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['not mentioned'],
#    'population': 'santalum austrocaledonicum in new caledonian archipelago',
#    'study_type': ['not mentioned'],
#    'focus': ['primary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to study the genetic diversity and structure of santalum austrocaledonicum in the new caledonian archipelago.',
#    'conclusion': 'the study indicates a strong influence of insularity on the genetic diversity and structure of santalum austrocaledonicum, with significant genetic differentiation among islands and a correlation between island age, isolation, and genetic diversity.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': [],
#    'location': 'new caledonia',
#    'mechanism': []}},
#  {'root_name': 'Sandalwood',
#   'synonyms': 'Sandalwood; sandalwood oil; Indian sandalwood; Australian sandalwood; Sandalwood resinoid; Santalum album; Santalum spicatum; Santalum austrocaledonicum',
#   'PMID': 15383230,
#   'pubmed_type': 'Evaluation Study',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['in vitro'],
#    'population': 'indian medicinal plants',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['not mentioned'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [{'ingredient': 'santalum album',
#      'daily_dosage': 250,
#      'units': 'microg/ml',
#      'original_text': '250 microg/mL'}],
#    'usage': ['not mentioned'],
#    'conditions': ['regulation of pathological conditions caused by excessive generation of no and its oxidation product, peroxynitrite'],
#    'biomarkers': ['nitric oxide'],
#    'functions': ['not mentioned'],
#    'purpose': 'to examine the regulatory effect of plant extracts on nitric oxide levels using sodium nitroprusside as an no donor in vitro.',
#    'conclusion': 'the present results suggest that these medicinal plants might be potent and novel therapeutic agents for scavenging of no and the regulation of pathological conditions caused by excessive generation of no and its oxidation product, peroxynitrite.',
#    'outcomes': [{'name': 'regulation of pathological conditions caused by excessive generation of no and its oxidation product, peroxynitrite',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not reported'},
#     {'name': 'nitric oxide',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': [],
#    'location': 'not mentioned',
#    'mechanism': []}},
#  {'root_name': 'Sandalwood',
#   'synonyms': 'Sandalwood; sandalwood oil; Indian sandalwood; Australian sandalwood; Sandalwood resinoid; Santalum album; Santalum spicatum; Santalum austrocaledonicum',
#   'PMID': 10904144,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': 'not mentioned',
#    'sample_size': 'not mentioned',
#    'sample_gender': ['not mentioned'],
#    'species': ['plants'],
#    'experimental_model': ['not mentioned'],
#    'population': 'plants used in ayurvedic rasayana for their therapeutic action',
#    'study_type': ['not mentioned'],
#    'focus': ['secondary'],
#    'benefits': ['antioxidant activity'],
#    'synergies_interactions_positive': ['not mentioned'],
#    'synergies_interactions_negative': ['not mentioned'],
#    'safety_side_effects': ['not mentioned'],
#    'interventions': [],
#    'usage': ['not mentioned'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to review the historical, etymological, morphological, phytochemical and pharmacological aspects of seven plants used in ayurvedic rasayana for their antioxidant activity',
#    'conclusion': 'the plants described contain antioxidant principles, which can explain and justify their use in traditional medicine in the past as well as the present.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': [],
#    'location': 'not mentioned',
#    'mechanism': []}}]

# %% [markdown]
# # Enriching Data

# %%
import json

ingredient_df_lookup = ingredient_df.set_index(["PMID",'Root Name'])[["Publication Year","NeuraciType","Synonyms","PubMed URL"]].to_dict(orient="index")


# Read JSON file
with open("output/test_10|31.json", "r", encoding="utf-8") as f:
    json_list = json.load(f)

# Add attributes 
for record in json_list:
    pmid = record["PMID"]
    root_name = record['root_name']
    record['synonyms'] = [s.strip() for s in record['synonyms'].split(';')]
    key = (pmid,root_name)
    if key in ingredient_df_lookup:
        lookup_data = ingredient_df_lookup[key]
        record.setdefault("metadata", {})  # ensure "metadata" exists
        record["metadata"]["published_year"] = lookup_data["Publication Year"]
        record["metadata"]["neuraci_type"] = lookup_data["NeuraciType"]
        #record["metadata"]["synonyms"] = lookup_data["Synonyms"]
        record["metadata"]["url"] = lookup_data["PubMed URL"]
# Save JSON file
with open("output/test_enriched_10|31.json", "w", encoding="utf-8") as f:
    json.dump(json_list, f, indent=2, ensure_ascii=False)

# %%
print(len(json_list))
# Out:
# 183

# %% [markdown]
# # Converting into Structured Data

# %%
import json
import pandas as pd

# # --- Step 1: Load JSON file ---
# with open("data.json", "r", encoding="utf-8") as f:
#     records = json.load(f)   # assuming it's a list of JSON objects

rows = []
records = json_list
# --- Step 2: Flatten each record ---
for rec in records:
    pmid = rec.get("PMID")
    root_name = rec.get("root_name")
    meta = rec.get("metadata", {})
    pubmed_type = rec.get("pubmed_type")

    row = {
        "root_name":root_name,
        "PMID": pmid,
        "synonyms":";".join(rec.get('synonyms',[])),
        "experimental_model":"".join(meta.get("experimental_model")),
        "published_year": meta.get("published_year"),
        "neuraci_type": meta.get("neuraci_type"),
        "pubmed_type":pubmed_type,
        "study_type": ";".join(meta.get('study_type')),
        "duration_days": meta.get("duration_days"),
        "sample_size": meta.get("sample_size"),
        "sample_gender": ";".join(meta.get("sample_gender", [])),
        "species": ";".join(meta.get("species", [])),
        "population": meta.get("population"),
        "purpose": meta.get("purpose"),
        "focus": "".join(meta.get("focus")),
        "benefits": ";".join(meta.get("benefits", [])),
        "synergies_interactions_positive": ";".join(meta.get("synergies_interactions_positive", [])),
        "synergies_interactions_negative": ";".join(meta.get("synergies_interactions_negative", [])),
        "safety_side_effects": ";".join(meta.get("safety_side_effects", [])),
        "conditions": ";".join(meta.get("conditions", [])),
        "biomarkers": ";".join(meta.get("biomarkers", [])),
        "symptoms": ";".join(meta.get("symptoms", [])),
        "keywords": ";".join(meta.get("keywords", [])),
        "diseases": ";".join(meta.get("diseases", [])),
        "mechanism": ";".join(meta.get("mechanism", [])),
        "usage": ";".join(meta.get("usage", [])),
        "location":meta.get("location"),
        "conclusion":meta.get("conclusion"),
        "url": meta.get("url", []),
    }

    # --- Expand interventions ---
    for i, iv in enumerate(meta.get("interventions", []), start=1):
        row[f"intervention{i}_ingredient"] = iv.get("ingredient")
        row[f"intervention{i}_daily_dosage"] = iv.get("daily_dosage")
        row[f"intervention{i}_units"] = iv.get("units")
        row[f"intervention{i}_original_text"] = iv.get("original_text")

    # --- Expand outcomes ---
    for j, oc in enumerate(meta.get("outcomes", []), start=1):
        row[f"outcome{j}_name"] = oc.get("name")
        row[f"outcome{j}_domain"] = oc.get("domain")
        row[f"outcome{j}_type"] = oc.get("type")
        row[f"outcome{j}_result"] = oc.get("result")

    rows.append(row)

# --- Step 3: Convert to DataFrame ---
output_df = pd.DataFrame(rows)

# --- Step 4: Save to CSV ---
output_df.to_csv("output/test_10|31.csv", index=False)
output_df.head()
# Out:
#    root_name      PMID                                           synonyms  \
# 0  Patchouli  40219102  Patchouli;patchouli oil;Pogostemon oil;patchou...
# 1  Patchouli  39511253  Patchouli;patchouli oil;Pogostemon oil;patchou...
# 2  Patchouli  38708994  Patchouli;patchouli oil;Pogostemon oil;patchou...
# 3  Patchouli  38623714  Patchouli;patchouli oil;Pogostemon oil;patchou...
# 4  Patchouli  38504994  Patchouli;patchouli oil;Pogostemon oil;patchou...
#
#   experimental_model  published_year                     neuraci_type  \
# 0      not mentioned            2025  Observational Studies & Reviews
# 1           in vitro            2024  Observational Studies & Reviews
# 2      not mentioned            2024  Observational Studies & Reviews
# 3    in vivoin vitro            2024  Observational Studies & Reviews
# 4    in vivoin vitro            2024  Observational Studies & Reviews
#
#          pubmed_type     study_type  duration_days    sample_size  ...  \
# 0             Review  not mentioned  not mentioned  not mentioned  ...
# 1  Comparative Study  not mentioned  not mentioned  not mentioned  ...
# 2             Review  not mentioned  not mentioned  not mentioned  ...
# 3             Review         review  not mentioned  not mentioned  ...
# 4             Review  not mentioned  not mentioned  not mentioned  ...
#
#   outcome31_type outcome31_result outcome32_name outcome32_domain  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   outcome32_type outcome32_result intervention3_ingredient  \
# 0            NaN              NaN                      NaN
# 1            NaN              NaN                      NaN
# 2            NaN              NaN                      NaN
# 3            NaN              NaN                      NaN
# 4            NaN              NaN                      NaN
#
#   intervention3_daily_dosage intervention3_units intervention3_original_text
# 0                        NaN                 NaN                         NaN
# 1                        NaN                 NaN                         NaN
# 2                        NaN                 NaN                         NaN
# 3                        NaN                 NaN                         NaN
# 4                        NaN                 NaN                         NaN
#
# [5 rows x 169 columns]

# %%
pd.set_option('display.max_columns', None)
