# %% [markdown]
# # Defining Types of Articles

# %%
systematic_meta_analysis = [
    "Meta-Analysis",
    "Network Meta-Analysis",
    "Systematic Review"
    ]

# %%
clinical_trial = [
    "Adaptive Clinical Trial",
    "Clinical Study",
    "Clinical Trial",
    "Clinical Trial Protocol",
    "Clinical Trial, Phase I",
    "Clinical Trial, Phase II",
    "Clinical Trial, Phase III",
    "Clinical Trial, Phase IV",
    "Clinical Trial, Veterinary",
    "Controlled Clinical Trial",
    "Equivalence Trial",
    "Multicenter Study",
    "Pragmatic Clinical Trial",
    "Randomized Controlled Trial",
    "Randomized Controlled Trial, Veterinary"
]

# %%
observational_studies = [
    "Case Reports",
    "Comparative Study",
    "Evaluation Study",
    "Observational Study",
    "Observational Study, Veterinary",
    "Twin Study",
    "Validation Study",
    "Review",
    "Scientific Integrity Review",
    "Scoping Review"
]

# %%
# Initialize an empty list
all_study_types = []

# Extend the list with other lists
all_study_types.extend(systematic_meta_analysis)
all_study_types.extend(clinical_trial)
all_study_types.extend(observational_studies)

allowed_study_types = all_study_types

# Print the combined list
print("Total Study types:",len(all_study_types))
# Out:
# Total Study types: 28

# %% [markdown]
# # Loading Data

# %%
import pandas as pd

# Read Excel file
df = pd.read_excel('Data/entrez_ingredients_with_synonyms.xlsx')  # For .xls or .xlsx

# View first 5 rows
df.head()
# Out:
#             Root Name      PMID  \
# 0  Acetyl L-Carnitine  10022226
# 1  Acetyl L-Carnitine  10030388
# 2  Acetyl L-Carnitine  10036643
# 3  Acetyl L-Carnitine  10052020
# 4  Acetyl L-Carnitine  10067662
#
#                                                Title  \
# 0     Micronutrients prevent cancer and delay aging.
# 1  Significance of skeletal muscle properties on ...
# 2  Cellular dysmetabolism: the dark side of HIV-1...
# 3  Substrate utilization and work efficiency duri...
# 4  L-carnitine improves glucose disposal in type ...
#
#                                         Article Type  Publication Year  \
# 0  Journal Article; Research Support, Non-U.S. Go...              1998
# 1  Comparative Study; Journal Article; Research S...              1999
# 2                            Journal Article; Review              1996
# 3  Clinical Trial; Controlled Clinical Trial; Jou...              1999
# 4  Clinical Trial; Controlled Clinical Trial; Jou...              1999
#
#                                   PubMed URL Search Term(s)
# 0  https://pubmed.ncbi.nlm.nih.gov/10022226/      Carnitine
# 1  https://pubmed.ncbi.nlm.nih.gov/10030388/      Carnitine
# 2  https://pubmed.ncbi.nlm.nih.gov/10036643/      Carnitine
# 3  https://pubmed.ncbi.nlm.nih.gov/10052020/      Carnitine
# 4  https://pubmed.ncbi.nlm.nih.gov/10067662/      Carnitine

# %%
df.shape
# Out:
# (277397, 7)

# %% [markdown]
# # Adding Synonyms

# %%
import numpy as np

synonyms_df = pd.read_excel("76 Ingredient List.xlsx")
synonyms_df['Common Name(s)'] = synonyms_df['Common Name(s)'].astype(str).str.replace(',', ';')
synonyms_df['Other Search Words'] = synonyms_df['Other Search Words'].astype(str).str.replace(',', ';')
synonyms_df = synonyms_df.replace(['nan', np.nan], '') 
synonyms_df['Synonyms'] = (
    synonyms_df['Common Name(s)'].fillna('')
    .str.strip() + '; ' +
    synonyms_df['Scientific Name(s)'].fillna('')
    .str.strip() + '; ' +
    synonyms_df['Other Search Words'].fillna('')
    .str.strip()
)
synonyms_df.head()
# Out:
#     Ingredient                                     Common Name(s)  \
# 0  Ashwagandha         Ashwagandha; Indian Ginseng; Winter Cherry
# 1    Chamomile  Chamomile; English Chamomile; German Chamomile...
# 2         GABA                                               GABA
# 3      Glycine                                 Glycine; L-Glycine
# 4   Lemon Balm             Melissa; Balm Mint; Lemon Balm Extract
#
#                                   Scientific Name(s)  \
# 0                                 Withania somnifera
# 1  Matricaria chamomilla; Chamaemelum nobile; Mat...
# 2                            Gamma-Aminobutyric Acid
# 3                                   Aminoacetic Acid
# 4                                Melissa officinalis
#
#           Other Search Words  \
# 0  Withanolide; Withanolides
# 1
# 2
# 3
# 4
#
#                                             Synonyms
# 0  Ashwagandha; Indian Ginseng; Winter Cherry; Wi...
# 1  Chamomile; English Chamomile; German Chamomile...
# 2                    GABA; Gamma-Aminobutyric Acid;
# 3             Glycine; L-Glycine; Aminoacetic Acid;
# 4  Melissa; Balm Mint; Lemon Balm Extract; Meliss...

# %%
df_merged = df.merge(
    synonyms_df[['Ingredient', 'Synonyms']],  # only the columns we need
    left_on='Root Name',               # key in df
    right_on='Ingredient',             # key in synonyms_df
    how='left'                         # keep all rows from df
)

# Drop duplicate 'Ingredient' column
df = df_merged.drop(columns=['Ingredient'])
df.head()
# Out:
#             Root Name      PMID  \
# 0  Acetyl L-Carnitine  10022226
# 1  Acetyl L-Carnitine  10030388
# 2  Acetyl L-Carnitine  10036643
# 3  Acetyl L-Carnitine  10052020
# 4  Acetyl L-Carnitine  10067662
#
#                                                Title  \
# 0     Micronutrients prevent cancer and delay aging.
# 1  Significance of skeletal muscle properties on ...
# 2  Cellular dysmetabolism: the dark side of HIV-1...
# 3  Substrate utilization and work efficiency duri...
# 4  L-carnitine improves glucose disposal in type ...
#
#                                         Article Type  Publication Year  \
# 0  Journal Article; Research Support, Non-U.S. Go...              1998
# 1  Comparative Study; Journal Article; Research S...              1999
# 2                            Journal Article; Review              1996
# 3  Clinical Trial; Controlled Clinical Trial; Jou...              1999
# 4  Clinical Trial; Controlled Clinical Trial; Jou...              1999
#
#                                   PubMed URL Search Term(s)  \
# 0  https://pubmed.ncbi.nlm.nih.gov/10022226/      Carnitine
# 1  https://pubmed.ncbi.nlm.nih.gov/10030388/      Carnitine
# 2  https://pubmed.ncbi.nlm.nih.gov/10036643/      Carnitine
# 3  https://pubmed.ncbi.nlm.nih.gov/10052020/      Carnitine
# 4  https://pubmed.ncbi.nlm.nih.gov/10067662/      Carnitine
#
#                                             Synonyms
# 0  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 1  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 2  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 3  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 4  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...

# %% [markdown]
# # Defining Neuraci Type

# %%
# Define mapping of NeuraciTypes
priority_mapping = [
    (systematic_meta_analysis,'Systematic Review & Meta Analysis'), # 1st Priority
    (clinical_trial, 'Clinical Trials'),                            # 2nd Priority
    (observational_studies, 'Observational Studies & Reviews'),     # 3rd Priority

]

# Function to assign NeuraciType based on priority
def classify_type(type_list):
    for reference_list, category in priority_mapping:
        if any(item in reference_list for item in type_list):
            return category
    return 'Unclassified'  # optional, in case nothing matches

# Function to assign NeuraciType based on priority and return the matched item
# def classify_type(type_list):
#     for reference_list, category in priority_mapping:
#         for item in type_list:
#             if item in reference_list:
#                 return category, item  # Return both category and matched item
#     return 'Unclassified', None  # Default if nothing matches


# Create new column with a list of article types
df['Type_list'] = df['Article Type'].apply(lambda x: set([item.strip() for item in x.split(';')]))


# Apply function to create new column
#df['PubMedType'] = df['Type_list'].apply(lambda x: x.intersection(set(allowed_study_types)))
df['PubMedType'] = df['Type_list'].apply(
    lambda x: ', '.join(x.intersection(set(allowed_study_types))) if isinstance(x, set) else ''
)
df["NeuraciType"] = df['Type_list'].apply(lambda x: pd.Series(classify_type(x)))

df.head()
# Out:
#             Root Name      PMID  \
# 0  Acetyl L-Carnitine  10022226
# 1  Acetyl L-Carnitine  10030388
# 2  Acetyl L-Carnitine  10036643
# 3  Acetyl L-Carnitine  10052020
# 4  Acetyl L-Carnitine  10067662
#
#                                                Title  \
# 0     Micronutrients prevent cancer and delay aging.
# 1  Significance of skeletal muscle properties on ...
# 2  Cellular dysmetabolism: the dark side of HIV-1...
# 3  Substrate utilization and work efficiency duri...
# 4  L-carnitine improves glucose disposal in type ...
#
#                                         Article Type  Publication Year  \
# 0  Journal Article; Research Support, Non-U.S. Go...              1998
# 1  Comparative Study; Journal Article; Research S...              1999
# 2                            Journal Article; Review              1996
# 3  Clinical Trial; Controlled Clinical Trial; Jou...              1999
# 4  Clinical Trial; Controlled Clinical Trial; Jou...              1999
#
#                                   PubMed URL Search Term(s)  \
# 0  https://pubmed.ncbi.nlm.nih.gov/10022226/      Carnitine
# 1  https://pubmed.ncbi.nlm.nih.gov/10030388/      Carnitine
# 2  https://pubmed.ncbi.nlm.nih.gov/10036643/      Carnitine
# 3  https://pubmed.ncbi.nlm.nih.gov/10052020/      Carnitine
# 4  https://pubmed.ncbi.nlm.nih.gov/10067662/      Carnitine
#
#                                             Synonyms  \
# 0  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 1  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 2  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 3  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
# 4  Carnitine; ALCAR; Acetylcarnitine; Acetyl L Ca...
#
#                                            Type_list  \
# 0  {Journal Article, Review, Research Support, No...
# 1  {Journal Article, Comparative Study, Research ...
# 2                          {Journal Article, Review}
# 3  {Journal Article, Research Support, Non-U.S. G...
# 4  {Journal Article, Controlled Clinical Trial, C...
#
#                                   PubMedType                      NeuraciType
# 0                                     Review  Observational Studies & Reviews
# 1                          Comparative Study  Observational Studies & Reviews
# 2                                     Review  Observational Studies & Reviews
# 3  Controlled Clinical Trial, Clinical Trial                  Clinical Trials
# 4  Controlled Clinical Trial, Clinical Trial                  Clinical Trials

# %%
ingredients = ["Cedarwood"]

# %%
from UPDATED_meta_data_generation import process_pmids

#ingredient_df = df[df['Root Name'].isin([10473175])]
ingredient_df = df[df['Root Name'].isin(ingredients)]
#ingredient_df = df[(df['Root Name'].isin(ingredients)) & (df['NeuraciType'] == 'Clinical Trials')]
#ingredient_df = duplicates_df[duplicates_df['PMID'].isin(pmids)]
process_pmids(ingredient_df['Root Name'],ingredient_df['Search Term(s)'],ingredient_df['Synonyms'],ingredient_df['PMID'], ingredient_df['PubMedType'],output_file="cedarwood_10|7.json")
# Out:
# Processing PMIDs:   0%|          | 0/97 [00:00<?, ?pmid/s]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:   1%|          | 1/97 [00:07<11:31,  7.21s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:   2%|▏         | 2/97 [00:12<09:12,  5.82s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:   3%|▎         | 3/97 [00:18<09:50,  6.28s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:   4%|▍         | 4/97 [00:29<12:13,  7.89s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:   5%|▌         | 5/97 [00:34<10:53,  7.11s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:   6%|▌         | 6/97 [00:39<09:24,  6.20s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:   7%|▋         | 7/97 [00:46<09:48,  6.54s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:   8%|▊         | 8/97 [00:51<08:51,  5.97s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:   9%|▉         | 9/97 [00:55<07:55,  5.40s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  10%|█         | 10/97 [01:09<11:34,  7.98s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  11%|█▏        | 11/97 [01:17<11:25,  7.97s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  12%|█▏        | 12/97 [01:28<12:34,  8.88s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  13%|█▎        | 13/97 [01:34<11:26,  8.18s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  14%|█▍        | 14/97 [01:39<09:57,  7.20s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  15%|█▌        | 15/97 [01:46<09:31,  6.97s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  16%|█▋        | 16/97 [01:51<08:55,  6.61s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  18%|█▊        | 17/97 [01:55<07:47,  5.84s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  19%|█▊        | 18/97 [02:01<07:33,  5.74s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  20%|█▉        | 19/97 [02:05<06:52,  5.28s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  21%|██        | 20/97 [02:08<06:00,  4.68s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  22%|██▏       | 21/97 [02:11<05:06,  4.04s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  23%|██▎       | 22/97 [02:23<07:52,  6.30s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  24%|██▎       | 23/97 [02:27<07:09,  5.80s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  25%|██▍       | 24/97 [02:37<08:27,  6.95s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  26%|██▌       | 25/97 [02:46<09:11,  7.66s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  27%|██▋       | 26/97 [02:58<10:25,  8.82s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  28%|██▊       | 27/97 [03:02<08:32,  7.32s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  30%|██▉       | 29/97 [03:07<05:30,  4.85s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  31%|███       | 30/97 [03:11<04:55,  4.41s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  32%|███▏      | 31/97 [03:18<05:42,  5.19s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  33%|███▎      | 32/97 [03:31<08:14,  7.61s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  34%|███▍      | 33/97 [03:34<06:36,  6.20s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  36%|███▌      | 35/97 [03:44<05:24,  5.23s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  37%|███▋      | 36/97 [03:48<04:56,  4.87s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  39%|███▉      | 38/97 [03:53<03:31,  3.59s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  40%|████      | 39/97 [03:58<03:42,  3.83s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  41%|████      | 40/97 [04:12<06:36,  6.96s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  42%|████▏     | 41/97 [04:16<05:44,  6.14s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  44%|████▍     | 43/97 [04:21<03:38,  4.04s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  45%|████▌     | 44/97 [04:30<05:01,  5.68s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  46%|████▋     | 45/97 [04:35<04:42,  5.42s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  47%|████▋     | 46/97 [04:53<07:44,  9.11s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  48%|████▊     | 47/97 [04:59<06:47,  8.14s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  49%|████▉     | 48/97 [05:13<08:16, 10.14s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  51%|█████     | 49/97 [05:17<06:33,  8.20s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  52%|█████▏    | 50/97 [05:30<07:34,  9.67s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  53%|█████▎    | 51/97 [05:33<05:57,  7.76s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  54%|█████▎    | 52/97 [05:41<05:50,  7.80s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  55%|█████▍    | 53/97 [05:54<06:51,  9.36s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  56%|█████▌    | 54/97 [06:01<06:01,  8.40s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  57%|█████▋    | 55/97 [06:04<04:55,  7.04s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  58%|█████▊    | 56/97 [06:11<04:49,  7.05s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  59%|█████▉    | 57/97 [06:21<05:08,  7.70s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  60%|█████▉    | 58/97 [06:23<04:02,  6.22s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  61%|██████    | 59/97 [06:29<03:53,  6.14s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  62%|██████▏   | 60/97 [06:43<05:12,  8.44s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  63%|██████▎   | 61/97 [06:48<04:27,  7.42s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  64%|██████▍   | 62/97 [06:52<03:40,  6.29s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  65%|██████▍   | 63/97 [06:56<03:09,  5.57s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  68%|██████▊   | 66/97 [07:05<01:47,  3.47s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  69%|██████▉   | 67/97 [07:09<01:47,  3.60s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  70%|███████   | 68/97 [07:13<01:50,  3.82s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  71%|███████   | 69/97 [07:19<01:58,  4.24s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  72%|███████▏  | 70/97 [07:23<02:00,  4.45s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  73%|███████▎  | 71/97 [07:27<01:51,  4.31s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  74%|███████▍  | 72/97 [07:32<01:47,  4.28s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  75%|███████▌  | 73/97 [07:47<03:00,  7.53s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  76%|███████▋  | 74/97 [07:51<02:29,  6.51s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  77%|███████▋  | 75/97 [08:00<02:38,  7.20s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  78%|███████▊  | 76/97 [08:04<02:12,  6.30s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  79%|███████▉  | 77/97 [08:11<02:11,  6.60s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  80%|████████  | 78/97 [08:16<01:54,  6.01s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  81%|████████▏ | 79/97 [08:21<01:45,  5.88s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  82%|████████▏ | 80/97 [08:25<01:26,  5.07s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  84%|████████▎ | 81/97 [08:30<01:20,  5.05s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  85%|████████▍ | 82/97 [08:33<01:08,  4.59s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  86%|████████▌ | 83/97 [08:37<00:59,  4.25s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  87%|████████▋ | 84/97 [08:43<01:02,  4.82s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  88%|████████▊ | 85/97 [08:50<01:07,  5.63s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  89%|████████▊ | 86/97 [08:55<00:57,  5.24s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  90%|████████▉ | 87/97 [09:06<01:10,  7.07s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  91%|█████████ | 88/97 [09:11<00:58,  6.47s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  92%|█████████▏| 89/97 [09:14<00:43,  5.41s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  93%|█████████▎| 90/97 [09:16<00:31,  4.55s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  94%|█████████▍| 91/97 [09:20<00:25,  4.24s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  95%|█████████▍| 92/97 [09:33<00:34,  6.81s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  96%|█████████▌| 93/97 [09:36<00:23,  5.87s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  97%|█████████▋| 94/97 [09:40<00:15,  5.12s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs:  99%|█████████▉| 96/97 [09:47<00:04,  4.02s/pmid]
# Synonyms Cedarwood; Cedrus;
# Processing PMIDs: 100%|██████████| 97/97 [09:51<00:00,  6.10s/pmid]
# [{'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 10473175,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': ['unspecified'],
#    'species': ['other'],
#    'population': 'turkish plants used in folk medicine for gastric ailments',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': ['anti-helicobacter pylori effect'],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'cedrus libani',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'cones of cedrus libani'}],
#    'usage': ['unspecified'],
#    'conditions': ['gastric ailments', 'peptic ulcers'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to study the anti-helicobacter pylori effect of extracts from turkish plants used in folk medicine for gastric ailments.',
#    'conclusion': 'the study found that extracts from six turkish plants, including cones of cedrus libani, showed activity against helicobacter pylori with mics between 1.95 and 250 microg/ml, except for spartium junceum which was inactive.',
#    'outcomes': [{'name': 'anti-helicobacter pylori effect',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': ['helicobacter pylori infection'],
#    'symptoms': [],
#    'keywords': ['anti-helicobacter pylori',
#     'turkish plants',
#     'folk medicine',
#     'gastric ailments',
#     'peptic ulcers',
#     'cedrus libani'],
#    'location': 'turkey',
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 11524119,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': None,
#    'sample_size': 137,
#    'sample_gender': ['unspecified'],
#    'species': ['other'],
#    'population': '137 species of gymnosperms belonging to 14 families',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': ['unspecified'],
#    'conditions': [],
#    'biomarkers': ['fatty acid composition',
#     'chloroplastic lipids',
#     'digalactosyldiacylglycerol',
#     'monogalactosyldiacylglycerol'],
#    'functions': [],
#    'purpose': 'to determine the fatty acid composition of photosynthetic tissues from gymnosperms and analyze the data using multivariate analyses.',
#    'conclusion': 'a clear-cut separation of the genera abies, larix, and cedrus from the other pinaceae was evidenced based on fatty acid composition.',
#    'outcomes': [{'name': 'fatty acid composition',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'chloroplastic lipids',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': 'digalactosyldiacylglycerol',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': 'monogalactosyldiacylglycerol',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['gymnosperms',
#     'fatty acid composition',
#     'cedrus',
#     'pinaceae',
#     'multivariate analyses'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 11876259,
#   'pubmed_type': 'Comparative Study, Review',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': ['other'],
#    'population': 'abietoid seed fatty acid compositions of the genera abies, cedrus, hesperopeuce, keteleeria, pseudolarix, and tsuga',
#    'study_type': ['review'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': [],
#    'biomarkers': ['delta5-olefinic acids',
#     'taxoleic acid',
#     'pinolenic acid',
#     'coniferonic acid',
#     'keteleeronic acid',
#     'sciadonic acid',
#     '14-methyl hexadecanoic acid'],
#    'functions': [],
#    'purpose': 'to review the seed fatty acid compositions of abietoids and make preliminary inferences on the taxonomy of pinaceae.',
#    'conclusion': "the study suggests that seed fatty acid compositions, particularly the presence of delta5-olefinic acids, may be useful in sustaining and adding precision to the taxonomy of the pinaceae family. it proposes the creation of a 'tsugoid' subfamily based on seed fatty acid patterns and other criteria.",
#    'outcomes': [{'name': 'delta5-olefinic acids',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': 'taxoleic acid',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': 'pinolenic acid',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': 'coniferonic acid',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': 'keteleeronic acid',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': 'sciadonic acid',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': '14-methyl hexadecanoic acid',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'not_reported'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['abietoid',
#     'seed fatty acid',
#     'pinaceae',
#     'delta5-olefinic acids',
#     'taxonomy',
#     'tsugoid subfamily'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 11876600,
#   'pubmed_type': 'Controlled Clinical Trial, Clinical Trial',
#   'metadata': {'duration_days': 730,
#    'sample_size': 23,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'patients with japanese cedar pollinosis',
#    'study_type': ['non-randomized trial'],
#    'focus': ['none'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'cs-560',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'cs-560'}],
#    'usage': ['unspecified'],
#    'conditions': ['japanese cedar pollinosis'],
#    'biomarkers': ['il-4', 'il-5', 'il-13', 'ifn-gamma'],
#    'functions': [],
#    'purpose': 'to evaluate the effect of japanese cedar-specific immunotherapy on cytokine production in peripheral blood mononuclear cells.',
#    'conclusion': 'specific immunotherapy for japanese cedar pollinosis using cs-560 clearly modified cytokine expression by peripheral blood mononuclear cells.',
#    'outcomes': [{'name': 'japanese cedar pollinosis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'il-4',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'il-5',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'il-13',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'ifn-gamma',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'no_effect'}],
#    'diseases': ['allergic rhinitis'],
#    'symptoms': [],
#    'keywords': ['japanese cedar',
#     'immunotherapy',
#     'cytokine production',
#     'peripheral blood mononuclear cells',
#     'cs-560',
#     'allergic rhinitis'],
#    'location': 'japan',
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 11896972,
#   'pubmed_type': 'Case Reports',
#   'metadata': {'duration_days': None,
#    'sample_size': 3,
#    'sample_gender': ['unspecified'],
#    'species': ['animals'],
#    'population': 'dogs with recurrent pruritic dermatitis',
#    'study_type': ['unspecified'],
#    'focus': ['none'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': ['atopic dermatitis'],
#    'biomarkers': ['ige specific to cry j 1', 'ige specific to cry j 2'],
#    'functions': [],
#    'purpose': 'to investigate the sensitivity of dogs to japanese cedar pollen allergen and its correlation with atopic dermatitis.',
#    'conclusion': 'cry j 1 was identified as the major allergen recognized by ige and lymphocytes, leading to type i hypersensitivity to japanese cedar pollen allergen in atopic dogs.',
#    'outcomes': [{'name': 'atopic dermatitis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'ige specific to cry j 1',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'ige specific to cry j 2',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'no_effect'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['atopic dermatitis',
#     'japanese cedar',
#     'cryptomeria japonica',
#     'ige',
#     'cry j 1',
#     'cry j 2',
#     'hypersensitivity'],
#    'location': 'japan',
#    'mechanism': ['type i hypersensitivity']}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 11962214,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': ['other'],
#    'population': 'resins obtained from the roots and stems of cedrus libani and abies cilicica',
#    'study_type': ['unspecified'],
#    'focus': ['primary'],
#    'benefits': ['highly effective against tested microorganisms by preventing their growth'],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'cedrus libani',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'ethanol extract of resins obtained from the roots and stems'},
#     {'ingredient': 'abies cilicica',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'ethanol extract of resins obtained from the roots and stems'}],
#    'usage': [],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to investigate the antimicrobial activity of the ethanol extract of resins obtained from the roots and stems of cedrus libani and abies cilicica',
#    'conclusion': 'crude extracts of the resins of both plants are highly effective against tested microorganisms by preventing their growth to a greater extent.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['antimicrobial activity',
#     'cedrus libani',
#     'abies cilicica',
#     'resins',
#     'ethanol extract'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 12003301,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'individuals in india affected by respiratory allergies',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': ['inhalation'],
#    'conditions': ['respiratory allergy'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to identify common environmental allergens causing respiratory allergies in india.',
#    'conclusion': 'cedrus deodara is identified as one of the allergenically important pollens contributing to respiratory allergies in india.',
#    'outcomes': [{'name': 'respiratory allergy',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['respiratory allergy',
#     'aeroallergens',
#     'cedrus deodara',
#     'pollen',
#     'fungal spores',
#     'dust mites',
#     'insects'],
#    'location': 'india',
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 12099344,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': ['other'],
#    'population': 'saccate pollen grains of seven podocarp species in five genera and saccate and non-saccate pollen of four other conifer genera, and spores of three fern species and one lycopod species',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to study the hydrodynamic properties of saccate pollen grains in relation to the pollination mechanism in prumnopitys species',
#    'conclusion': 'the combination of buoyancy and wettability in saccate pollen has implications for the efficiency of the typical podocarp pollination mechanism.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['saccate pollen',
#     'hydrodynamics',
#     'pollination mechanism',
#     'prumnopitys',
#     'podocarpaceae'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 1215003,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': ['other'],
#    'population': 'cedrus libani mature pollen from 3 culture areas (italy, france, ussr)',
#    'study_type': ['unspecified'],
#    'focus': ['primary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to analyze the development of cedar of lebanon (cedrus libani) pollen grains in cultural plantings.',
#    'conclusion': 'the study found that 69-71% of cedrus libani pollen grains have two-celled protallium and antheridial cell, with up to 30% sterility due to abortive spore development. anomalous cenocyte and multinuclear pollen grains suggest the potential for multicellular haploid structures to arise during natural anther development.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['cedrus libani',
#     'pollen grain development',
#     'cytological study',
#     'pollen sterility',
#     'anomalous cenocyte',
#     'multinuclear pollen grains'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 12543163,
#   'pubmed_type': 'Clinical Trial',
#   'metadata': {'duration_days': None,
#    'sample_size': 37,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'patients with cedar pollinosis',
#    'study_type': ['non-randomized trial'],
#    'focus': ['secondary'],
#    'benefits': ['it might control symptoms to mild ones and might control worsening of symptoms after substantial pollen scattering'],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': ['there was only one case of mild dizziness (2.7%), and no other adverse reactions such as sleepiness were observed'],
#    'interventions': [{'ingredient': 'fexofenadine hydrochloride',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'one tablet of the drug twice daily'}],
#    'usage': ['ingestion'],
#    'conditions': ['cedar pollinosis'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to investigate the therapeutic efficacy of fexofenadine hydrochloride in patients with cedar pollinosis by comparing early-treatment and therapeutic-treatment groups.',
#    'conclusion': 'fexofenadine hydrochloride administered in patients with cedar pollinosis from before substantial pollen scattering might control their symptoms to mild ones and might control worsening of their symptoms after the substantial pollen scattering, and, therefore, the drug was considered to be useful in early therapy.',
#    'outcomes': [{'name': 'sneeze',
#      'domain': 'symptom',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': ['sneeze'],
#    'keywords': ['fexofenadine hydrochloride',
#     'cedar pollinosis',
#     'antihistaminic',
#     'early therapy',
#     'symptom control'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedarwood',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 12805340,
#   'pubmed_type': 'Randomized Controlled Trial, Clinical Trial',
#   'metadata': {'duration_days': None,
#    'sample_size': 313,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'patients undergoing radiotherapy',
#    'study_type': ['double-blind trial', 'randomized controlled trial'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'cedarwood',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'pure essential oils of lavender, bergamot, and cedarwood administered by inhalation'}],
#    'usage': ['inhalation'],
#    'conditions': ['anxiety'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to determine whether the inhalation of aromatherapy during radiotherapy reduces anxiety.',
#    'conclusion': 'aromatherapy, as administered in this study, is not beneficial.',
#    'outcomes': [{'name': 'anxiety',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'no_effect'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['inhalation aromatherapy',
#     'radiotherapy',
#     'anxiety',
#     'double-blind randomized trial',
#     'cedarwood'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedarwood',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 14614968,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': None,
#    'sample_size': 26,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'healthy human subjects',
#    'study_type': ['unspecified'],
#    'focus': ['primary'],
#    'benefits': ['induced behavioral changes including sedative effects'],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'cedrol',
#      'daily_dosage': 71,
#      'units': 'microg',
#      'original_text': '14.2+/-1.7 microg/l, 5 l/min'}],
#    'usage': ['inhalation'],
#    'conditions': [],
#    'biomarkers': ['heart rate',
#     'systolic blood pressure',
#     'diastolic blood pressure',
#     'respiratory rate',
#     'baroreceptor sensitivity',
#     'high frequency component',
#     'low frequency to high frequency components ratio',
#     'low frequency components of systolic blood pressure variability',
#     'low frequency components of diastolic blood pressure variability'],
#    'functions': ['autonomic functions',
#     'cardiovascular functions',
#     'respiratory functions'],
#    'purpose': 'to analyze cardiovascular and respiratory functions while subjects were inhaling fumes of pure compound cedrol extracted from cedar wood oil.',
#    'conclusion': 'cedrol inhalation induced an increase in parasympathetic activity and a reduction in sympathetic activity, consistent with the idea of a relaxant effect of cedrol.',
#    'outcomes': [{'name': 'heart rate',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'systolic blood pressure',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'diastolic blood pressure',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'respiratory rate',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'baroreceptor sensitivity',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'high frequency component',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'low frequency to high frequency components ratio',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'low frequency components of systolic blood pressure variability',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'low frequency components of diastolic blood pressure variability',
#      'domain': 'biomarker',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['cedrol',
#     'cedar wood',
#     'autonomic responses',
#     'inhalation',
#     'cardiovascular functions',
#     'respiratory functions',
#     'parasympathetic activity',
#     'sympathetic activity',
#     'relaxant effect'],
#    'location': None,
#    'mechanism': ['increase in parasympathetic activity',
#     'reduction in sympathetic activity']}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 14677902,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'individuals in india suffering from allergic diseases such as bronchial asthma, allergic rhinitis, and atopic dermatitis.',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': ['unspecified'],
#    'conditions': ['allergic diseases',
#     'bronchial asthma',
#     'allergic rhinitis',
#     'atopic dermatitis'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to provide an overview of aeroallergens in clinical practice of allergy in india and their impact on allergic diseases.',
#    'conclusion': 'cedrus is identified as one of the predominant airborne pollen and allergenically important pollen in india, contributing to allergic diseases such as bronchial asthma, allergic rhinitis, and atopic dermatitis.',
#    'outcomes': [{'name': 'allergic diseases',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'bronchial asthma',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': 'allergic rhinitis',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not_reported'},
#     {'name': 'atopic dermatitis',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'not_reported'}],
#    'diseases': ['allergic diseases'],
#    'symptoms': [],
#    'keywords': ['aeroallergens',
#     'allergic diseases',
#     'bronchial asthma',
#     'allergic rhinitis',
#     'atopic dermatitis',
#     'pollen',
#     'cedrus',
#     'cross-reactivity',
#     'immunotherapy'],
#    'location': 'india',
#    'mechanism': ['cross-reactivity of ige antibodies']}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedarwood',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 15080642,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': ['other'],
#    'population': 'cedarwood chips from juniperus virginianna',
#    'study_type': ['unspecified'],
#    'focus': ['primary'],
#    'benefits': ['extraction of cedarwood oil using liquid carbon dioxide'],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'cedarwood oil',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'extraction of cedarwood oil using liquid carbon dioxide'}],
#    'usage': [],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to investigate the extraction of cedarwood oil using liquid carbon dioxide and compare it to supercritical fluid extraction.',
#    'conclusion': 'the extraction of cedarwood oil using liquid carbon dioxide was investigated and compared to supercritical fluid extraction, with the highest extraction rate under supercritical conditions. differences in chemical composition were observed, with a higher cedrol/cedrene ratio at lower temperatures and pressures.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['cedarwood oil',
#     'liquid carbon dioxide',
#     'supercritical fluid extraction',
#     'cedrol',
#     'cedrene'],
#    'location': None,
#    'mechanism': ['dehydration of cedrol to cedrene']}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 15153076,
#   'pubmed_type': 'Randomized Controlled Trial, Clinical Trial',
#   'metadata': {'duration_days': 28,
#    'sample_size': 84,
#    'sample_gender': ['unspecified'],
#    'species': ['animals'],
#    'population': '72 growing sheep with sarcoptic mange, aged 5-6 months and weighing 20.4-31.7 kg',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': ['recovery was faster with ascorbic acid as an adjunct therapy when compared with the group treated with the drug alone'],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'cedrus deodara',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'oil of cedrus deodara'},
#     {'ingredient': 'ascorbic acid',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'ascorbic acid was administered intramuscularly'}],
#    'usage': ['topical', 'injection'],
#    'conditions': ['sarcoptic mange'],
#    'biomarkers': ['total erythrocytes',
#     'leucocytes',
#     'haematocrit',
#     'haemoglobin',
#     'lymphocytes'],
#    'functions': [],
#    'purpose': 'to evaluate the therapeutic efficacy of commonly used acaricidal drugs in india and assess the effect of ascorbic acid as adjunct therapy in growing sheep with sarcoptic mange',
#    'conclusion': 'oil of jatropha curcas was found more efficacious in controlling sarcoptic mange in sheep and ascorbic acid might be beneficial as adjunct in case of sarcoptic mange to get quick recovery with lesser applications of main therapy.',
#    'outcomes': [{'name': 'sarcoptic mange',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'total erythrocytes',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'leucocytes',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'haematocrit',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'haemoglobin',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'lymphocytes',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['sarcoptic mange',
#     'cedrus deodara',
#     'ascorbic acid',
#     'sheep',
#     'immune responses',
#     'pathology'],
#    'location': 'india',
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 15153077,
#   'pubmed_type': 'Randomized Controlled Trial, Clinical Trial',
#   'metadata': {'duration_days': 60,
#    'sample_size': 72,
#    'sample_gender': ['unspecified'],
#    'species': ['animals'],
#    'population': '72 growing sheep with sarcoptic mange, aged 5-6 months and weighing 20.4-31.7 kg',
#    'study_type': ['non-randomized trial'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'cedrus deodara',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'oil of cedrus deodara'},
#     {'ingredient': 'pongamia glabra',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'oil of pongamia glabra'},
#     {'ingredient': 'jatropha curcas',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'oil of jatropha curcas'},
#     {'ingredient': 'benzyl benzoate',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'benzyl benzoate'},
#     {'ingredient': 'ascorbic acid',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'ascorbic acid'}],
#    'usage': ['topical', 'injection'],
#    'conditions': ['sarcoptic mange'],
#    'biomarkers': ['bromosulphophthalein retention time'],
#    'functions': ['weight gain',
#     'liver function',
#     'nutrient digestibility',
#     'wool production',
#     'meat quality'],
#    'purpose': 'to evaluate the therapeutic efficacy of commonly used acaricidal drugs in india and assess the effect of ascorbic acid as adjunct therapy in sheep with sarcoptic mange.',
#    'conclusion': 'ojc was the better therapy for sarcoptic mange of sheep and ascorbic acid as adjunct therapy is advisable. ojc-aa therapy may be better from the point of view of improving wool yield and meat production.',
#    'outcomes': [{'name': 'sarcoptic mange',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'bromosulphophthalein retention time',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'weight gain',
#      'domain': 'function',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'liver function',
#      'domain': 'function',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'nutrient digestibility',
#      'domain': 'function',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'wool production',
#      'domain': 'function',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'meat quality',
#      'domain': 'function',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['sarcoptic mange',
#     'cedrus deodara',
#     'pongamia glabra',
#     'jatropha curcas',
#     'benzyl benzoate',
#     'ascorbic acid',
#     'weight gain',
#     'liver function',
#     'nutrient digestibility',
#     'wool production',
#     'meat quality'],
#    'location': 'india',
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 15750743,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': ['other'],
#    'population': 'perennial crops and trees in pakistan',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': ['stem rot', 'butt rot', 'root rot'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to study diseases caused by ganoderma spp. on perennial crops in pakistan.',
#    'conclusion': 'ganoderma spp. attack species including cedrus in pakistan, causing stem, butt, and root rot diseases.',
#    'outcomes': [{'name': 'stem rot',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'butt rot',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'root rot',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'}],
#    'diseases': ['stem rot', 'butt rot', 'root rot'],
#    'symptoms': [],
#    'keywords': ['ganoderma spp.',
#     'perennial crops',
#     'pakistan',
#     'cedrus',
#     'stem rot',
#     'butt rot',
#     'root rot'],
#    'location': 'pakistan',
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 15841671,
#   'pubmed_type': 'Validation Study',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'patients with japanese cedar pollinosis',
#    'study_type': ['unspecified'],
#    'focus': ['none'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': ['allergic rhinitis'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to elucidate whether the new patient satisfaction questionnaire for allergic rhinitis has good and reliable clinical validity.',
#    'conclusion': 'the study found that the new patient satisfaction questionnaire for allergic rhinitis demonstrated good clinical validity, with higher satisfaction scores in the jaac group compared to the jsr group, suggesting its reliability in evaluating patient satisfaction.',
#    'outcomes': [{'name': 'patient satisfaction',
#      'domain': 'function',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['patient satisfaction',
#     'allergic rhinitis',
#     'japanese cedar pollinosis',
#     'clinical validity',
#     'questionnaire'],
#    'location': 'japan',
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 15849424,
#   'pubmed_type': 'Randomized Controlled Trial, Clinical Trial',
#   'metadata': {'duration_days': 98,
#    'sample_size': None,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'cedar pollinosis patients',
#    'study_type': ['double-blind trial'],
#    'focus': ['none'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': ['no adverse reactions were induced by apple polyphenol during the study'],
#    'interventions': [{'ingredient': 'apple polyphenol',
#      'daily_dosage': 500,
#      'units': 'mg',
#      'original_text': '500 mg once daily'}],
#    'usage': ['ingestion'],
#    'conditions': ['cedar pollinosis'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to evaluate the treatment efficacy of apple polyphenol for cedar pollinosis.',
#    'conclusion': 'apple polyphenol may alleviate the symptoms of cedar pollinosis, as the sneezing score was significantly lower for the apple polyphenol group than with the placebo group during the early and main pollen dispersion periods.',
#    'outcomes': [{'name': 'sneezing score',
#      'domain': 'symptom',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': ['sneezing'],
#    'keywords': ['apple polyphenol',
#     'cedar pollinosis',
#     'double-blind study',
#     'allergic rhinitis'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 15907076,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': ['unspecified'],
#    'species': ['other'],
#    'population': 'lebanon cedar trees in antalya',
#    'study_type': ['unspecified'],
#    'focus': ['primary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': ['unspecified'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to test the precision of some published competition indices of lebanon cedar for the estimation of future periodic diameter increment of individual trees.',
#    'conclusion': 'competition indices with larger influence-zone areas produce better results for predicting periodic diameter increment of lebanon cedar trees.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['competition indices',
#     'lebanon cedar',
#     'diameter increment',
#     'stand models'],
#    'location': 'turkey',
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 15930574,
#   'pubmed_type': 'Evaluation Study, Comparative Study',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': [],
#    'population': '',
#    'study_type': ['unspecified'],
#    'focus': ['none'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to study the fermentability of the water-soluble portion obtained by supercritical water treatment of lignocellulosics to ethanol.',
#    'conclusion': 'treatment with wood charcoal can be effective at removing inhibitors and improving the fermentability of the water-soluble portion without reducing the levels of fermentable sugars.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['fermentability',
#     'water-soluble portion',
#     'supercritical water treatment',
#     'lignocellulosics',
#     'ethanol',
#     'wood charcoal',
#     'furan',
#     'phenolic compounds',
#     'sugar fermentability'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 15955653,
#   'pubmed_type': 'Controlled Clinical Trial',
#   'metadata': {'duration_days': None,
#    'sample_size': 169,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'patients of cedar pollenosis',
#    'study_type': ['non-randomized trial'],
#    'focus': ['none'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'trichloroacetic acid',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': '80w/v% trichloroacetic acid (TCA)'}],
#    'usage': ['topical'],
#    'conditions': ['japanese cedar pollenosis'],
#    'biomarkers': ['histamine', 'eosinophil cationic protein'],
#    'functions': [],
#    'purpose': 'to investigate the effectiveness of chemosurgery with trichloroacetic acid for the treatment of japanese cedar pollenosis.',
#    'conclusion': 'regional suppression of the allergic reaction to japanese cedar pollen appears to occur as a result of chemosurgery with trichloroacetic acid performed as a day surgery.',
#    'outcomes': [{'name': 'japanese cedar pollenosis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'},
#     {'name': 'histamine',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'eosinophil cationic protein',
#      'domain': 'biomarker',
#      'type': 'secondary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['chemosurgery',
#     'trichloroacetic acid',
#     'japanese cedar pollenosis',
#     'chemical mediators',
#     'nasal provocation test'],
# ...
#     {'name': 'microbial infections',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'joint disorders',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'asthma',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'kidney stones',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'ulcer',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'brain disorders',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'immunological disorders',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'bone fractures',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'sprains',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'rheumatism',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'boils',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'leprosy',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'cancer',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'diabetes',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'arthritis',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'neurological disorders',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'gastric disturbances',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'},
#     {'name': 'inflammation',
#      'domain': 'condition',
#      'type': 'secondary',
#      'result': 'improved'}],
#    'diseases': ['cancer', 'diabetes', 'arthritis', 'asthma', 'leprosy'],
#    'symptoms': [],
#    'keywords': ['cedrus deodara',
#     'traditional use',
#     'phytochemical composition',
#     'pharmacology',
#     'terpenoids',
#     'flavonoids',
#     'bioactive compounds',
#     'cedrin',
#     'himachalol',
#     'himachalene',
#     'atlantone'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 34832920,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': ['other'],
#    'population': 'essential oils and their compounds',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': ['antiviral potential against sars-cov-2'],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to identify the most promising essential oil compounds against sars-cov-2 based on their physicochemical, pharmacokinetic, and toxicity properties.',
#    'conclusion': 'fifteen essential oil compounds were considered the most promising against sars-cov-2 with the adme/t index ranging from 0.86 to 0.81, and some plant species were identified as potential sources with anti-sars-cov-2 activity, including cedrus libani.',
#    'outcomes': [],
#    'diseases': ['covid-19'],
#    'symptoms': [],
#    'keywords': ['essential oils',
#     'sars-cov-2',
#     'antiviral potential',
#     'cedrus libani',
#     'chemometric approach'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedarwood',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 35917731,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': [],
#    'population': '',
#    'study_type': ['unspecified'],
#    'focus': ['none'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to discuss regulatory expectation, sources and magnitudes of instrument- and sample-derived uncertainties, use of reference standards, and algorithms for comparing spectra in quality-regulated environments.',
#    'conclusion': 'the ideas discussed support the use of circular dichroism not only in quality-regulated environments but also best practice when used in a research environment.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['circular dichroism',
#     'biopharmaceutical proteins',
#     'quality-regulated environment',
#     'regulatory expectation',
#     'instrument performance',
#     'spectra comparison'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 36364121,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': [],
#    'population': 'selected bark essential oils',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to provide an overview of barks that are economically, medicinally, and ethnopharmaceutically relevant.',
#    'conclusion': 'essential oils extracted from the bark of trees, including cedrus deodara, have not been researched as extensively as from other plant components, highlighting the need for further research.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['essential oils',
#     'bark oils',
#     'cedrus deodara',
#     'chemistry',
#     'biological activities'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 38539820,
#   'pubmed_type': 'Review',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': [],
#    'species': ['other'],
#    'population': 'essential oils from pinaceae species',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': ['antioxidant effects'],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': [],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to review the antioxidant activity of essential oils from pinaceae species, including cedrus.',
#    'conclusion': 'essential oils from abies and cedrus have been more extensively investigated for their chemical composition and biological or pharmacological properties, including antioxidant effects.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['antioxidant activity',
#     'essential oils',
#     'pinaceae',
#     'cedrus',
#     'abies',
#     'pinus',
#     'picea',
#     'gymnosperms'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedarwood; Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 38794141,
#   'pubmed_type': 'Scoping Review',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'patients with inflammatory skin conditions such as acne vulgaris, dermatitis and eczema, psoriasis, and rosacea',
#    'study_type': ['randomized controlled trial',
#     'non-randomized trial',
#     'unspecified'],
#    'focus': ['secondary'],
#    'benefits': ['potential efficacy of cedarwood oil in the treatment of acne'],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'cedarwood oil',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'cedarwood (cedrus libani) oil'}],
#    'usage': ['topical'],
#    'conditions': ['inflammatory skin conditions',
#     'acne vulgaris',
#     'dermatitis',
#     'eczema',
#     'psoriasis',
#     'rosacea'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to generate a broad overview of the essential oils used to treat inflammatory skin conditions in a clinical setting',
#    'conclusion': 'the uncontrolled studies indicated the potential efficacy of cedarwood oil in the treatment of acne, but further research is required to reach conclusive evidence.',
#    'outcomes': [{'name': 'inflammatory skin conditions',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'acne vulgaris',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'dermatitis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'eczema',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'psoriasis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'},
#     {'name': 'rosacea',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'not_reported'}],
#    'diseases': ['acne vulgaris',
#     'dermatitis',
#     'eczema',
#     'psoriasis',
#     'rosacea'],
#    'symptoms': [],
#    'keywords': ['essential oils',
#     'inflammatory skin conditions',
#     'acne',
#     'dermatitis',
#     'eczema',
#     'psoriasis',
#     'rosacea',
#     'cedarwood oil'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 39069654,
#   'pubmed_type': 'Case Reports',
#   'metadata': {'duration_days': None,
#    'sample_size': 1,
#    'sample_gender': ['female'],
#    'species': ['humans'],
#    'population': 'a 60-year-old female with no underlying disease scheduled for general anesthesia for a left-cochlear implant operation',
#    'study_type': ['case report'],
#    'focus': ['none'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'rocuronium',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'intravenous injection of rocuronium'}],
#    'usage': ['injection'],
#    'conditions': ['epiglottis adhesion'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to report a case of successful management in a patient with unexpected hidden vocal cords due to epiglottis adhesion to the posterior wall of the laryngeal cavity',
#    'conclusion': "the patient's airway was successfully managed using a technique that combined a video-styletscope with a video-laryngoscope.",
#    'outcomes': [{'name': 'epiglottis adhesion',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['epiglottis adhesion',
#     'intubation',
#     'video-styletscope',
#     'video-laryngoscope',
#     'anesthesia'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 7859708,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': None,
#    'sample_size': None,
#    'sample_gender': ['unspecified'],
#    'species': ['other'],
#    'population': 'seed storage proteins from gymnosperms',
#    'study_type': ['unspecified'],
#    'focus': ['secondary'],
#    'benefits': [],
#    'synergies_interactions_positive': [],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [],
#    'usage': ['unspecified'],
#    'conditions': [],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to characterize the seed storage proteins from seven gymnosperm species using electrophoretic analysis.',
#    'conclusion': 'the study clarifies knowledge of gymnosperm seed storage proteins, indicating the presence of proteins similar to 7s globulins in all species studied, with specific cross-reactivity observed in pinaceae species.',
#    'outcomes': [],
#    'diseases': [],
#    'symptoms': [],
#    'keywords': ['sds-page',
#     'pgge',
#     'western blot',
#     'seed storage proteins',
#     'gymnosperms',
#     'pinaceae',
#     'cupressaceae',
#     'taxaceae',
#     '7s globulins',
#     '11s protein'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedrus',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 9418375,
#   'pubmed_type': 'Comparative Study',
#   'metadata': {'duration_days': 7,
#    'sample_size': 24,
#    'sample_gender': ['unspecified'],
#    'species': ['animals'],
#    'population': 'swiss mice',
#    'study_type': ['comparative study'],
#    'focus': ['primary'],
#    'benefits': ['himachalol provided 60% protection with increased mean survival time against invasive aspergillosis.'],
#    'synergies_interactions_positive': ['a combination of himachalol plus scz showed better regimen in the therapy evidenced by enhanced survival of mice.'],
#    'synergies_interactions_negative': [],
#    'safety_side_effects': [],
#    'interventions': [{'ingredient': 'himachalol',
#      'daily_dosage': 200,
#      'units': 'mg/kg',
#      'original_text': 'himachalol (200 mg kg-1, po) once a day, for 7 days'},
#     {'ingredient': 'scz',
#      'daily_dosage': 5,
#      'units': 'mg/kg',
#      'original_text': 'scz (5 mgkg-1)'}],
#    'usage': ['ingestion'],
#    'conditions': ['invasive aspergillosis'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to compare in vitro techniques for testing of antifungals and evaluate the efficacy of himachalol against a. fumigatus.',
#    'conclusion': 'himachalol from cedrus deodara provided significant protection against invasive aspergillosis in swiss mice, with enhanced survival when combined with scz.',
#    'outcomes': [{'name': 'invasive aspergillosis',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': ['aspergillosis'],
#    'symptoms': [],
#    'keywords': ['himachalol',
#     'cedrus deodara',
#     'invasive aspergillosis',
#     'antifungals',
#     'a. fumigatus'],
#    'location': None,
#    'mechanism': []}},
#  {'root_name': 'Cedarwood',
#   'search_term': 'Cedarwood',
#   'synonyms': 'Cedarwood; Cedrus; ',
#   'PMID': 9828867,
#   'pubmed_type': 'Randomized Controlled Trial, Clinical Trial',
#   'metadata': {'duration_days': 210,
#    'sample_size': 86,
#    'sample_gender': ['unspecified'],
#    'species': ['humans'],
#    'population': 'patients with alopecia areata',
#    'study_type': ['randomized controlled trial', 'double-blind trial'],
#    'focus': ['primary'],
#    'benefits': ['aromatherapy with cedarwood is a safe and effective treatment for alopecia areata'],
#    'synergies_interactions_positive': ['none'],
#    'synergies_interactions_negative': ['none'],
#    'safety_side_effects': ['none'],
#    'interventions': [{'ingredient': 'cedarwood',
#      'daily_dosage': None,
#      'units': '',
#      'original_text': 'massaged essential oils (thyme, rosemary, lavender, and cedarwood) in a mixture of carrier oils (jojoba and grapeseed) into their scalp daily'}],
#    'usage': ['topical'],
#    'conditions': ['alopecia areata'],
#    'biomarkers': [],
#    'functions': [],
#    'purpose': 'to investigate the efficacy of aromatherapy in the treatment of patients with alopecia areata.',
#    'conclusion': 'aromatherapy with cedarwood and other essential oils was significantly more effective than treatment with carrier oil alone for alopecia areata.',
#    'outcomes': [{'name': 'alopecia areata',
#      'domain': 'condition',
#      'type': 'primary',
#      'result': 'improved'}],
#    'diseases': ['alopecia areata'],
#    'symptoms': [],
#    'keywords': ['aromatherapy',
#     'alopecia areata',
#     'essential oils',
#     'cedarwood',
#     'randomized controlled trial'],
#    'location': None,
#    'mechanism': []}}]

# %% [markdown]
# # Enriching Data

# %%
import json

ingredient_df_lookup = ingredient_df.set_index(["PMID",'Root Name'])[["Publication Year","NeuraciType","Synonyms","PubMed URL"]].to_dict(orient="index")


# Read JSON file
with open("cedarwood_10|7.json", "r", encoding="utf-8") as f:
    json_list = json.load(f)

# Add attributes 
for record in json_list:
    pmid = record["PMID"]
    root_name = record['root_name']
    key = (pmid,root_name)
    if key in ingredient_df_lookup:
        lookup_data = ingredient_df_lookup[key]
        record.setdefault("metadata", {})  # ensure "metadata" exists
        record["metadata"]["published_year"] = lookup_data["Publication Year"]
        record["metadata"]["neuraci_type"] = lookup_data["NeuraciType"]
        #record["metadata"]["synonyms"] = lookup_data["Synonyms"]
        record["metadata"]["url"] = lookup_data["PubMed URL"]

# Save JSON file
with open("cedarwood_modified_enriched.json", "w", encoding="utf-8") as f:
    json.dump(json_list, f, indent=2, ensure_ascii=False)

# %% [markdown]
# # Converting into Structured Data

# %%
import json
import pandas as pd

# # --- Step 1: Load JSON file ---
# with open("data.json", "r", encoding="utf-8") as f:
#     records = json.load(f)   # assuming it's a list of JSON objects

rows = []
records = json_list
# --- Step 2: Flatten each record ---
for rec in records:
    pmid = rec.get("PMID")
    root_name = rec.get("root_name")
    search_term = rec.get("search_term")
    meta = rec.get("metadata", {})
    pubmed_type = rec.get("pubmed_type")
    synonyms = rec.get('synonyms')

    row = {
        "root_name":root_name,
        "Search Term(s)":search_term,
        "PMID": pmid,
        "synonyms":synonyms,
        "published_year": meta.get("published_year"),
        "neuraci_type": meta.get("neuraci_type"),
        "pubmed_type":pubmed_type,
        "study_type": ";".join(meta.get('study_type')),
        "duration_days": meta.get("duration_days"),
        "sample_size": meta.get("sample_size"),
        "sample_gender": ";".join(meta.get("sample_gender", [])),
        "species": ";".join(meta.get("species", [])),
        "population": meta.get("population"),
        "purpose": meta.get("purpose"),
        "focus": "".join(meta.get("focus")),
        "benefits": ";".join(meta.get("benefits", [])),
        "synergies_interactions_positive": ";".join(meta.get("synergies_interactions_positive", [])),
        "synergies_interactions_negative": ";".join(meta.get("synergies_interactions_negative", [])),
        "safety_side_effects": ";".join(meta.get("safety_side_effects", [])),
        "conditions": ";".join(meta.get("conditions", [])),
        "biomarkers": ";".join(meta.get("biomarkers", [])),
        "symptoms": ";".join(meta.get("symptoms", [])),
        "keywords": ";".join(meta.get("keywords", [])),
        "diseases": ";".join(meta.get("diseases", [])),
        "mechanism": ";".join(meta.get("mechanism", [])),
        "usage": ";".join(meta.get("usage", [])),
        "conclusion":meta.get("conclusion"),
        "url": meta.get("url", []),
    }

    # --- Expand interventions ---
    for i, iv in enumerate(meta.get("interventions", []), start=1):
        row[f"intervention{i}_ingredient"] = iv.get("ingredient")
        row[f"intervention{i}_daily_dosage"] = iv.get("daily_dosage")
        row[f"intervention{i}_units"] = iv.get("units")
        row[f"intervention{i}_original_text"] = iv.get("original_text")

    # --- Expand outcomes ---
    for j, oc in enumerate(meta.get("outcomes", []), start=1):
        row[f"outcome{j}_name"] = oc.get("name")
        row[f"outcome{j}_domain"] = oc.get("domain")
        row[f"outcome{j}_type"] = oc.get("type")
        row[f"outcome{j}_result"] = oc.get("result")

    rows.append(row)

# --- Step 3: Convert to DataFrame ---
output_df = pd.DataFrame(rows)

# --- Step 4: Save to CSV ---
output_df.to_csv("Cedarwood_modified_output.csv", index=False)
output_df.head()
# Out:
#    root_name Search Term(s)      PMID             synonyms  published_year  \
# 0  Cedarwood         Cedrus  10473175  Cedarwood; Cedrus;             1999
# 1  Cedarwood         Cedrus  11524119  Cedarwood; Cedrus;             2001
# 2  Cedarwood         Cedrus  11876259  Cedarwood; Cedrus;             2002
# 3  Cedarwood         Cedrus  11876600  Cedarwood; Cedrus;             2002
# 4  Cedarwood         Cedrus  11896972  Cedarwood; Cedrus;             2002
#
#                       neuraci_type                                pubmed_type  \
# 0  Observational Studies & Reviews                          Comparative Study
# 1  Observational Studies & Reviews                          Comparative Study
# 2  Observational Studies & Reviews                  Comparative Study, Review
# 3                  Clinical Trials  Controlled Clinical Trial, Clinical Trial
# 4  Observational Studies & Reviews                               Case Reports
#
#              study_type  duration_days  sample_size  ... outcome17_type  \
# 0           unspecified            NaN          NaN  ...            NaN
# 1           unspecified            NaN        137.0  ...            NaN
# 2                review            NaN          NaN  ...            NaN
# 3  non-randomized trial          730.0         23.0  ...            NaN
# 4           unspecified            NaN          3.0  ...            NaN
#
#   outcome17_result outcome18_name outcome18_domain outcome18_type  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#   outcome18_result outcome19_name outcome19_domain outcome19_type  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#   outcome19_result
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 124 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
output_df.head()
# Out:
#    root_name Search Term(s)      PMID             synonyms  published_year  \
# 0  Cedarwood         Cedrus  10473175  Cedarwood; Cedrus;             1999
# 1  Cedarwood         Cedrus  11524119  Cedarwood; Cedrus;             2001
# 2  Cedarwood         Cedrus  11876259  Cedarwood; Cedrus;             2002
# 3  Cedarwood         Cedrus  11876600  Cedarwood; Cedrus;             2002
# 4  Cedarwood         Cedrus  11896972  Cedarwood; Cedrus;             2002
#
#                       neuraci_type                                pubmed_type  \
# 0  Observational Studies & Reviews                          Comparative Study
# 1  Observational Studies & Reviews                          Comparative Study
# 2  Observational Studies & Reviews                  Comparative Study, Review
# 3                  Clinical Trials  Controlled Clinical Trial, Clinical Trial
# 4  Observational Studies & Reviews                               Case Reports
#
#              study_type  duration_days  sample_size sample_gender  species  \
# 0           unspecified            NaN          NaN   unspecified    other
# 1           unspecified            NaN        137.0   unspecified    other
# 2                review            NaN          NaN                  other
# 3  non-randomized trial          730.0         23.0   unspecified   humans
# 4           unspecified            NaN          3.0   unspecified  animals
#
#                                           population  \
# 0  turkish plants used in folk medicine for gastr...
# 1  137 species of gymnosperms belonging to 14 fam...
# 2  abietoid seed fatty acid compositions of the g...
# 3            patients with japanese cedar pollinosis
# 4            dogs with recurrent pruritic dermatitis
#
#                                              purpose      focus  \
# 0  to study the anti-helicobacter pylori effect o...  secondary
# 1  to determine the fatty acid composition of pho...  secondary
# 2  to review the seed fatty acid compositions of ...  secondary
# 3  to evaluate the effect of japanese cedar-speci...       none
# 4  to investigate the sensitivity of dogs to japa...       none
#
#                           benefits synergies_interactions_positive  \
# 0  anti-helicobacter pylori effect
# 1
# 2
# 3
# 4
#
#   synergies_interactions_negative safety_side_effects  \
# 0
# 1
# 2
# 3
# 4
#
#                        conditions  \
# 0  gastric ailments;peptic ulcers
# 1
# 2
# 3       japanese cedar pollinosis
# 4               atopic dermatitis
#
#                                           biomarkers symptoms  \
# 0
# 1  fatty acid composition;chloroplastic lipids;di...
# 2  delta5-olefinic acids;taxoleic acid;pinolenic ...
# 3                          il-4;il-5;il-13;ifn-gamma
# 4    ige specific to cry j 1;ige specific to cry j 2
#
#                                             keywords  \
# 0  anti-helicobacter pylori;turkish plants;folk m...
# 1  gymnosperms;fatty acid composition;cedrus;pina...
# 2  abietoid;seed fatty acid;pinaceae;delta5-olefi...
# 3  japanese cedar;immunotherapy;cytokine producti...
# 4  atopic dermatitis;japanese cedar;cryptomeria j...
#
#                         diseases                mechanism        usage  \
# 0  helicobacter pylori infection                           unspecified
# 1                                                          unspecified
# 2
# 3              allergic rhinitis                           unspecified
# 4                                 type i hypersensitivity
#
#                                           conclusion  \
# 0  the study found that extracts from six turkish...
# 1  a clear-cut separation of the genera abies, la...
# 2  the study suggests that seed fatty acid compos...
# 3  specific immunotherapy for japanese cedar poll...
# 4  cry j 1 was identified as the major allergen r...
#
#                                          url intervention1_ingredient  \
# 0  https://pubmed.ncbi.nlm.nih.gov/10473175/            cedrus libani
# 1  https://pubmed.ncbi.nlm.nih.gov/11524119/                      NaN
# 2  https://pubmed.ncbi.nlm.nih.gov/11876259/                      NaN
# 3  https://pubmed.ncbi.nlm.nih.gov/11876600/                   cs-560
# 4  https://pubmed.ncbi.nlm.nih.gov/11896972/                      NaN
#
#    intervention1_daily_dosage intervention1_units intervention1_original_text  \
# 0                         NaN                          cones of cedrus libani
# 1                         NaN                 NaN                         NaN
# 2                         NaN                 NaN                         NaN
# 3                         NaN                                          cs-560
# 4                         NaN                 NaN                         NaN
#
#                      outcome1_name outcome1_domain outcome1_type  \
# 0  anti-helicobacter pylori effect       condition       primary
# 1           fatty acid composition       biomarker       primary
# 2            delta5-olefinic acids       biomarker     secondary
# 3        japanese cedar pollinosis       condition       primary
# 4                atopic dermatitis       condition       primary
#
#   outcome1_result            outcome2_name outcome2_domain outcome2_type  \
# 0        improved                      NaN             NaN           NaN
# 1    not_reported     chloroplastic lipids       biomarker     secondary
# 2    not_reported            taxoleic acid       biomarker     secondary
# 3        improved                     il-4       biomarker     secondary
# 4        improved  ige specific to cry j 1       biomarker       primary
#
#   outcome2_result               outcome3_name outcome3_domain outcome3_type  \
# 0             NaN                         NaN             NaN           NaN
# 1    not_reported  digalactosyldiacylglycerol       biomarker     secondary
# 2    not_reported              pinolenic acid       biomarker     secondary
# 3        improved                        il-5       biomarker     secondary
# 4        improved     ige specific to cry j 2       biomarker     secondary
#
#   outcome3_result                 outcome4_name outcome4_domain outcome4_type  \
# 0             NaN                           NaN             NaN           NaN
# 1    not_reported  monogalactosyldiacylglycerol       biomarker     secondary
# 2    not_reported              coniferonic acid       biomarker     secondary
# 3        improved                         il-13       biomarker     secondary
# 4       no_effect                           NaN             NaN           NaN
#
#   outcome4_result      outcome5_name outcome5_domain outcome5_type  \
# 0             NaN                NaN             NaN           NaN
# 1    not_reported                NaN             NaN           NaN
# 2    not_reported  keteleeronic acid       biomarker     secondary
# 3        improved          ifn-gamma       biomarker     secondary
# 4             NaN                NaN             NaN           NaN
#
#   outcome5_result   outcome6_name outcome6_domain outcome6_type  \
# 0             NaN             NaN             NaN           NaN
# 1             NaN             NaN             NaN           NaN
# 2    not_reported  sciadonic acid       biomarker     secondary
# 3       no_effect             NaN             NaN           NaN
# 4             NaN             NaN             NaN           NaN
#
#   outcome6_result                outcome7_name outcome7_domain outcome7_type  \
# 0             NaN                          NaN             NaN           NaN
# 1             NaN                          NaN             NaN           NaN
# 2    not_reported  14-methyl hexadecanoic acid       biomarker     secondary
# 3             NaN                          NaN             NaN           NaN
# 4             NaN                          NaN             NaN           NaN
#
#   outcome7_result intervention2_ingredient  intervention2_daily_dosage  \
# 0             NaN                      NaN                         NaN
# 1             NaN                      NaN                         NaN
# 2    not_reported                      NaN                         NaN
# 3             NaN                      NaN                         NaN
# 4             NaN                      NaN                         NaN
#
#   intervention2_units intervention2_original_text outcome8_name  \
# 0                 NaN                         NaN           NaN
# 1                 NaN                         NaN           NaN
# 2                 NaN                         NaN           NaN
# 3                 NaN                         NaN           NaN
# 4                 NaN                         NaN           NaN
#
#   outcome8_domain outcome8_type outcome8_result outcome9_name outcome9_domain  \
# 0             NaN           NaN             NaN           NaN             NaN
# 1             NaN           NaN             NaN           NaN             NaN
# 2             NaN           NaN             NaN           NaN             NaN
# 3             NaN           NaN             NaN           NaN             NaN
# 4             NaN           NaN             NaN           NaN             NaN
#
#   outcome9_type outcome9_result intervention3_ingredient  \
# 0           NaN             NaN                      NaN
# 1           NaN             NaN                      NaN
# 2           NaN             NaN                      NaN
# 3           NaN             NaN                      NaN
# 4           NaN             NaN                      NaN
#
#    intervention3_daily_dosage intervention3_units intervention3_original_text  \
# 0                         NaN                 NaN                         NaN
# 1                         NaN                 NaN                         NaN
# 2                         NaN                 NaN                         NaN
# 3                         NaN                 NaN                         NaN
# 4                         NaN                 NaN                         NaN
#
#   intervention4_ingredient  intervention4_daily_dosage intervention4_units  \
# 0                      NaN                         NaN                 NaN
# 1                      NaN                         NaN                 NaN
# 2                      NaN                         NaN                 NaN
# 3                      NaN                         NaN                 NaN
# 4                      NaN                         NaN                 NaN
#
#   intervention4_original_text intervention5_ingredient  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
#
#    intervention5_daily_dosage intervention5_units intervention5_original_text  \
# 0                         NaN                 NaN                         NaN
# 1                         NaN                 NaN                         NaN
# 2                         NaN                 NaN                         NaN
# 3                         NaN                 NaN                         NaN
# 4                         NaN                 NaN                         NaN
#
#   outcome10_name outcome10_domain outcome10_type outcome10_result  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   outcome11_name outcome11_domain outcome11_type outcome11_result  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   outcome12_name outcome12_domain outcome12_type outcome12_result  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   outcome13_name outcome13_domain outcome13_type outcome13_result  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   outcome14_name outcome14_domain outcome14_type outcome14_result  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   outcome15_name outcome15_domain outcome15_type outcome15_result  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   outcome16_name outcome16_domain outcome16_type outcome16_result  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   outcome17_name outcome17_domain outcome17_type outcome17_result  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   outcome18_name outcome18_domain outcome18_type outcome18_result  \
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
#
#   outcome19_name outcome19_domain outcome19_type outcome19_result
# 0            NaN              NaN            NaN              NaN
# 1            NaN              NaN            NaN              NaN
# 2            NaN              NaN            NaN              NaN
# 3            NaN              NaN            NaN              NaN
# 4            NaN              NaN            NaN              NaN
