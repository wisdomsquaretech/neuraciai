# %%
#pip -q install --upgrade biopython "pandas<2.3.0" tqdm openpyxl

# %%
#pip install openpyxl

# %%
from pubmed_scraper import pubmed_ingredient_search
pubmed_ingredient_search("Data", "Data", "Progress")
# Out:
# 🚀 Beginning PubMed scraper...
# 🆕 Starting fresh: no prior records found in raw CSV.
# [1/10] ▶️ Patchouli: known_before=0
# [1/10] Patchouli: hits_unfiltered=414, hits_filtered=46
# Patchouli | combined:   0%|          | 0/46 [00:00<?, ?papers/s]
# [1/10] Patchouli: processed=46 record(s) from API
# [1/10] ✅ Patchouli: hits_unfiltered=414, hits_filtered=46, new_this_run=46, total_known=46
# [2/10] ▶️ Saffron: known_before=0
# [2/10] Saffron: hits_unfiltered=2381, hits_filtered=615
# Saffron | combined:   0%|          | 0/615 [00:00<?, ?papers/s]
# [2/10] Saffron: processed=612 record(s) from API
# [2/10] ✅ Saffron: hits_unfiltered=2381, hits_filtered=615, new_this_run=612, total_known=612
# [3/10] ▶️ Jasmine: known_before=0
# [3/10] Jasmine: hits_unfiltered=638, hits_filtered=100
# Jasmine | combined:   0%|          | 0/100 [00:00<?, ?papers/s]
# [3/10] Jasmine: processed=99 record(s) from API
# ...
